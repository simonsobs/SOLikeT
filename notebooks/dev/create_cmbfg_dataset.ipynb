# %% [markdown]
# # Create a smooth fiducial for SOLikeT/MFLike
#
# In this notebook, we generate a fiducial smooth (i.e., binned spectrum-based theoretical prediction, no map-based random realization) dataset. We start from cmb+fg spectra (MFLike).

# %%
# %matplotlib inline
import os
import tempfile

import camb
import cobaya
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

print("     Numpy :", np.__version__)
print("Matplotlib :", mpl.__version__)
print("      CAMB :", camb.__version__)
print("    Cobaya :", cobaya.__version__)
# Out:
#      Numpy : 1.24.3
# Matplotlib : 3.8.0
#       CAMB : 1.5.0
#     Cobaya : 3.3.2

# %%
# Fiducial cosmo params. When used in a MCMC, the smooth data must agree with this input values

# set neutrino masses
m1=0
m2=np.sqrt(7.5e-5)
m3=np.sqrt(2.5e-3)

sumnu=m1+m2+m3

f1=m1/sumnu
f2=m2/sumnu
f3=m3/sumnu

print('sumnu =', sumnu)
print('')
print('f1 =', f1, '\nf2 =', f2, '\nf3 =', f3)

cosmo_params = {
    "cosmomc_theta": 0.0104090,
    "logA": {"value": 3.045, "drop": True},
    "As": {"value": "lambda logA: 1e-10*np.exp(logA)"},
    "ombh2": 0.02236,
    "omch2": 0.1202,
    "ns": 0.9649,
    "Alens": 1.0,
    "tau": 0.0544,
    "mnu": sumnu,
    "nnu": 3.044,
}

fg_params = {
    "a_tSZ": 3.30,
    "a_kSZ": 1.60,
    "a_p": 6.90,
    "beta_p": 2.08,
    "a_c": 4.90,
    "beta_c": 2.20,
    "a_s": 3.10,
    "T_d": 9.60,
    "a_gtt": 2.81,
    "a_gte": 0.10,
    "a_gee": 0.10,
    "a_psee": 0.000,
    "a_pste": 0.000,
    "xi": 0.20,
}

nuisance_params = {
    "bandint_shift_93": 0,  # only ideal values for now
    "bandint_shift_145": 0,
    "bandint_shift_225": 0,
    "cal_LAT_93": 1,
    "cal_LAT_145": 1,
    "cal_LAT_225": 1,
    "calT_LAT_93": 1,
    "calT_LAT_145": 1,
    "calT_LAT_225": 1,
    "calE_LAT_93": 1,
    "calE_LAT_145": 1,
    "calE_LAT_225": 1,
    "calG_all": 1,
    "alpha_LAT_93": 0,
    "alpha_LAT_145": 0,
    "alpha_LAT_225": 0,
}
# Out:
# sumnu = 0.05866025403784439
#
# f1 = 0.0
# f2 = 0.14763410387308012
# f3 = 0.8523658961269198

# %% [markdown]
# Let's use SOLikeT/MFLike to generate the fiducial spectra

# %%
packages_path = "/Users/bradamante/Google Drive/My Drive/Work/Projects/Open/cobaya_packages/"

# %%
pre = "LAT_simu_sacc_"
info = {
    "likelihood": {
        "soliket.MFLike": {
            "data_folder": "MFLike/v0.8",
            "input_file": pre + "00000.fits",
            "cov_Bbl_file": "data_sacc_w_covar_and_Bbl.fits",
            "defaults": {"polarizations": ['TT', 'TE', 'ET', 'EE'],
                         "scales": {"TT": [30, 9000],
                                    "TE": [30, 9000],
                                    "ET": [30, 9000],
                                    "EE": [30, 9000]},
                         "symmetrize": False
                        }
        }
    },
    "theory": {"camb": {"extra_args": {"lens_potential_accuracy": 1,
                                       "WantTransfer": True,
                                       "Transfer.high_precision": True,
                                       "Transfer.kmax": 1.2,
                                       "num_nu_massless": 1.044, #we use the minimal normal ordering case: massless lightest state, m2 and m3 computed according to oscilation measurements
                                       "num_nu_massive": 2, 
                                       "nu_mass_eigenstates": 2, 
                                       "nu_mass_fractions": [f2,f3],
                                       "nu_mass_numbers": [1,1],
                                       "share_delta_neff": True},
                        "stop_at_error": True}},
    "params": cosmo_params,
    "packages_path": packages_path,
    "debug": True,
}

# %%
info["theory"]["soliket.TheoryForge_MFLike"] = {"spectra": {"polarizations": ["tt", "te", "ee"],
                                                            "lmin": 2,
                                                            "lmax": 9050},
                                                'stop_at_error': True}
info["theory"]["soliket.Foreground"] = {'stop_at_error': True}
info["theory"]["soliket.BandPass"] = {'stop_at_error': True}

# %%
from cobaya.model import get_model

model = get_model(info)
# Out:
#  2023-10-04 15:42:19,183 [input] 'soliket.TheoryForge_MFLike' could not be found as internal, trying external.
#  2023-10-04 15:42:46,933 [tensorflow] Falling back to TensorFlow client; we recommended you install the Cloud TPU client directly with pip install cloud-tpu-client.
#  2023-10-04 15:42:47,331 [h5py._conv] Creating converter from 7 to 5
#  2023-10-04 15:42:47,332 [h5py._conv] Creating converter from 5 to 7
#  2023-10-04 15:42:47,333 [h5py._conv] Creating converter from 7 to 5
#  2023-10-04 15:42:47,334 [h5py._conv] Creating converter from 5 to 7
#  2023-10-04 15:42:49,663 [input] 'soliket.Foreground' could not be found as internal, trying external.
#  2023-10-04 15:42:49,669 [input] 'soliket.BandPass' could not be found as internal, trying external.
#  2023-10-04 15:42:49,672 [input] 'soliket.MFLike' could not be found as internal, trying external.
#  2023-10-04 15:42:49,686 [model] Input info updated with defaults (dumped to YAML):
# theory:
#   camb:
#     version: null
#     path: null
#     speed: 0.3
#     stop_at_error: true
#     extra_args:
#       lens_potential_accuracy: 1
#       WantTransfer: true
#       Transfer.high_precision: true
#       Transfer.kmax: 1.2
#       num_nu_massless: 1.044
#       num_nu_massive: 2
#       nu_mass_eigenstates: 2
#       nu_mass_fractions:
#       - 0.14763410387308012
#       - 0.8523658961269198
#       nu_mass_numbers:
#       - 1
#       - 1
#       share_delta_neff: true
#     ignore_obsolete: false
#     use_renames: false
#     external_primordial_pk: false
#     renames:
#       omegabh2: ombh2
#       omegach2: omch2
#       omegal: omega_de
#       omegak: omk
#       yhe: YHe
#       yheused: YHe
#       YpBBN: Y_p
#   soliket.TheoryForge_MFLike:
#     data_folder: MFLike/v0.6
#     exp_ch:
#     - LAT_93
#     - LAT_145
#     - LAT_225
#     eff_freqs:
#     - 93
#     - 145
#     - 225
#     spectra:
#       polarizations:
#       - tt
#       - te
#       - ee
#       lmin: 2
#       lmax: 9050
#     systematics_template: null
#     params:
#       cal_LAT_93:
#         value: 1
#         latex: \mathrm{Cal}_{\rm LAT}^{93}
#       cal_LAT_145:
#         value: 1
#         latex: \mathrm{Cal}_{\rm LAT}^{145}
#       cal_LAT_225:
#         value: 1
#         latex: \mathrm{Cal}_{\rm LAT}^{225}
#       calT_LAT_93:
#         value: 1
#         latex: \mathrm{Cal}_{\rm LAT, T}^{93}
#       calE_LAT_93:
#         value: 1
#         latex: \mathrm{Cal}_{\rm LAT, E}^{93}
#       calT_LAT_145:
#         value: 1
#         latex: \mathrm{Cal}_{\rm LAT, T}^{145}
#       calE_LAT_145:
#         value: 1
#         latex: \mathrm{Cal}_{\rm LAT, E}^{145}
#       calT_LAT_225:
#         value: 1
#         latex: \mathrm{Cal}_{\rm LAT, T}^{225}
#       calE_LAT_225:
#         value: 1
#         latex: \mathrm{Cal}_{\rm LAT, E}^{225}
#       calG_all:
#         value: 1
#         latex: \mathrm{Cal}_{\rm G}^{\rm All}
#       alpha_LAT_93:
#         value: 0
#         latex: \alpha_{\rm LAT}^{93}
#       alpha_LAT_145:
#         value: 0
#         latex: \alpha_{\rm LAT}^{145}
#       alpha_LAT_225:
#         value: 0
#         latex: \alpha_{\rm LAT}^{225}
#     speed: -1
#     stop_at_error: true
#     version: null
#   soliket.Foreground:
#     spectra:
#       polarizations:
#       - tt
#       - te
#       - ee
#       lmin: 2
#       lmax: 9000
#       exp_ch:
#       - LAT_150
#       eff_freqs:
#       - 150.0
#     foregrounds:
#       normalisation:
#         nu_0: 150.0
#         ell_0: 3000
#         T_CMB: 2.725
#       components:
#         tt:
#         - kSZ
#         - tSZ_and_CIB
#         - cibp
#         - dust
#         - radio
#         te:
#         - radio
#         - dust
#         ee:
#         - radio
#         - dust
#     params:
#       a_tSZ:
#         prior:
#           min: 3.0
#           max: 3.6
#         proposal: 0.05
#         latex: a_\mathrm{tSZ}
#       a_kSZ:
#         prior:
#           min: 1.4
#           max: 1.8
#         proposal: 0.1
#         latex: a_\mathrm{kSZ}
#       a_p:
#         prior:
#           min: 6.2
#           max: 7.6
#         proposal: 0.075
#         latex: a_p
#       beta_p:
#         prior:
#           min: 1.8
#           max: 2.2
#         proposal: 0.015
#         latex: \beta_p
#       a_c:
#         prior:
#           min: 4.4
#           max: 5.4
#         proposal: 0.12
#         latex: a_c
#       beta_c:
#         prior:
#           min: 2.0
#           max: 2.4
#         proposal: 0.03
#         latex: \beta_c
#       a_s:
#         prior:
#           min: 2.8
#           max: 3.4
#         proposal: 0.01
#         latex: a_s
#       a_gtt:
#         prior:
#           dist: norm
#           loc: 2.79
#           scale: 0.45
#         proposal: 0.4
#         latex: a_\mathrm{dust}^\mathrm{TT}
#       a_gte:
#         prior:
#           dist: norm
#           loc: 0.36
#           scale: 0.04
#         proposal: 0.04
#         latex: a_\mathrm{dust}^\mathrm{TE}
#       a_gee:
#         prior:
#           dist: norm
#           loc: 0.13
#           scale: 0.03
#         proposal: 0.03
#         latex: a_\mathrm{dust}^\mathrm{EE}
#       a_psee:
#         prior:
#           min: 0
#         proposal: 0.05
#         latex: a_\mathrm{ps}^\mathrm{EE}
#       a_pste:
#         prior:
#           min: -1
#           max: 1
#         proposal: 0.05
#         latex: a_\mathrm{ps}^\mathrm{TE}
#       xi:
#         prior:
#           min: 0
#           max: 0.2
#         proposal: 0.05
#         latex: \xi
#       T_d:
#         prior:
#           min: 8.6
#           max: 10.6
#         proposal: 0.6
#         latex: T_d
#     speed: -1
#     stop_at_error: true
#     version: null
#   soliket.BandPass:
#     data_folder: MFLike/v0.8
#     top_hat_band: null
#     external_bandpass: null
#     read_from_sacc: true
#     params:
#       bandint_shift_LAT_93:
#         value: 0
#         latex: \Delta_{\rm LAT}^{93}
#       bandint_shift_LAT_145:
#         value: 0
#         latex: \Delta_{\rm LAT}^{145}
#       bandint_shift_LAT_225:
#         value: 0
#         latex: \Delta_{\rm LAT}^{225}
#     speed: -1
#     stop_at_error: true
#     version: null
# likelihood:
#   soliket.MFLike:
#     data_folder: MFLike/v0.8
#     input_file: LAT_simu_sacc_00000.fits
#     cov_Bbl_file: data_sacc_w_covar_and_Bbl.fits
#     lmax_theory: null
#     defaults:
#       polarizations:
#       - TT
#       - TE
#       - ET
#       - EE
#       scales:
#         TT:
#         - 30
#         - 9000
#         TE:
#         - 30
#         - 9000
#         ET:
#         - 30
#         - 9000
#         EE:
#         - 30
#         - 9000
#       symmetrize: false
#     data:
#       experiments:
#       - LAT_93
#       - LAT_145
#       - LAT_225
#       spectra:
#       - experiments:
#         - LAT_93
#         - LAT_93
#       - experiments:
#         - LAT_93
#         - LAT_145
#       - experiments:
#         - LAT_93
#         - LAT_225
#       - experiments:
#         - LAT_145
#         - LAT_145
#       - experiments:
#         - LAT_145
#         - LAT_225
#       - experiments:
#         - LAT_225
#         - LAT_225
#     name: Gaussian
#     datapath: null
#     covpath: null
#     ncovsims: null
#     type: []
#     speed: -1
#     stop_at_error: false
#     version: null
# params:
#   cosmomc_theta:
#     value: 0.010409
#   logA:
#     value: 3.045
#     drop: true
#   As:
#     value: 'lambda logA: 1e-10*np.exp(logA)'
#     derived: true
#   ombh2:
#     value: 0.02236
#     renames:
#     - omegabh2
#   omch2:
#     value: 0.1202
#     renames:
#     - omegach2
#   ns:
#     value: 0.9649
#   Alens:
#     value: 1.0
#   tau:
#     value: 0.0544
#   mnu:
#     value: 0.05866025403784439
#   nnu:
#     value: 3.044
#   cal_LAT_93:
#     value: 1
#     latex: \mathrm{Cal}_{\rm LAT}^{93}
#   cal_LAT_145:
#     value: 1
#     latex: \mathrm{Cal}_{\rm LAT}^{145}
#   cal_LAT_225:
#     value: 1
#     latex: \mathrm{Cal}_{\rm LAT}^{225}
#   calT_LAT_93:
#     value: 1
#     latex: \mathrm{Cal}_{\rm LAT, T}^{93}
#   calE_LAT_93:
#     value: 1
#     latex: \mathrm{Cal}_{\rm LAT, E}^{93}
#   calT_LAT_145:
#     value: 1
#     latex: \mathrm{Cal}_{\rm LAT, T}^{145}
#   calE_LAT_145:
#     value: 1
#     latex: \mathrm{Cal}_{\rm LAT, E}^{145}
#   calT_LAT_225:
#     value: 1
#     latex: \mathrm{Cal}_{\rm LAT, T}^{225}
#   calE_LAT_225:
#     value: 1
#     latex: \mathrm{Cal}_{\rm LAT, E}^{225}
#   calG_all:
#     value: 1
#     latex: \mathrm{Cal}_{\rm G}^{\rm All}
#   alpha_LAT_93:
#     value: 0
#     latex: \alpha_{\rm LAT}^{93}
#   alpha_LAT_145:
#     value: 0
#     latex: \alpha_{\rm LAT}^{145}
#   alpha_LAT_225:
#     value: 0
#     latex: \alpha_{\rm LAT}^{225}
#   a_tSZ:
#     prior:
#       min: 3.0
#       max: 3.6
#     proposal: 0.05
#     latex: a_\mathrm{tSZ}
#   a_kSZ:
#     prior:
#       min: 1.4
#       max: 1.8
#     proposal: 0.1
#     latex: a_\mathrm{kSZ}
#   a_p:
#     prior:
#       min: 6.2
#       max: 7.6
#     proposal: 0.075
#     latex: a_p
#   beta_p:
#     prior:
#       min: 1.8
#       max: 2.2
#     proposal: 0.015
#     latex: \beta_p
#   a_c:
#     prior:
#       min: 4.4
#       max: 5.4
#     proposal: 0.12
#     latex: a_c
#   beta_c:
#     prior:
#       min: 2.0
#       max: 2.4
#     proposal: 0.03
#     latex: \beta_c
#   a_s:
#     prior:
#       min: 2.8
#       max: 3.4
#     proposal: 0.01
#     latex: a_s
#   a_gtt:
#     prior:
#       dist: norm
#       loc: 2.79
#       scale: 0.45
#     proposal: 0.4
#     latex: a_\mathrm{dust}^\mathrm{TT}
#   a_gte:
#     prior:
#       dist: norm
#       loc: 0.36
#       scale: 0.04
#     proposal: 0.04
#     latex: a_\mathrm{dust}^\mathrm{TE}
#   a_gee:
#     prior:
#       dist: norm
#       loc: 0.13
#       scale: 0.03
#     proposal: 0.03
#     latex: a_\mathrm{dust}^\mathrm{EE}
#   a_psee:
#     prior:
#       min: 0
#     proposal: 0.05
#     latex: a_\mathrm{ps}^\mathrm{EE}
#   a_pste:
#     prior:
#       min: -1
#       max: 1
#     proposal: 0.05
#     latex: a_\mathrm{ps}^\mathrm{TE}
#   xi:
#     prior:
#       min: 0
#       max: 0.2
#     proposal: 0.05
#     latex: \xi
#   T_d:
#     prior:
#       min: 8.6
#       max: 10.6
#     proposal: 0.6
#     latex: T_d
#   bandint_shift_LAT_93:
#     value: 0
#     latex: \Delta_{\rm LAT}^{93}
#   bandint_shift_LAT_145:
#     value: 0
#     latex: \Delta_{\rm LAT}^{145}
#   bandint_shift_LAT_225:
#     value: 0
#     latex: \Delta_{\rm LAT}^{225}
# packages_path: /Users/bradamante/Google Drive/My Drive/Work/Projects/Open/cobaya_packages/
# debug: true
#
#  2023-10-04 15:42:49,697 [camb] Attempting import of Cobaya-installed version, but defaulting to global import if not found.
#  2023-10-04 15:42:49,698 [camb] No (compiled) installation of 'camb' at /Users/bradamante/Library/CloudStorage/GoogleDrive-grbmtn@unife.it/My Drive/Work/Projects/Open/cobaya_packages/code/CAMB: Could not find compiled CAMB library camblib.so in /Users/bradamante/Library/CloudStorage/GoogleDrive-grbmtn@unife.it/My Drive/Work/Projects/Open/cobaya_packages/code/CAMB.
#  2023-10-04 15:42:49,698 [camb] Defaulting to global import.
#  2023-10-04 15:42:49,699 [camb] `camb` module loaded successfully from /Users/bradamante/miniconda/envs/soliket-tests/lib/python3.10/site-packages/camb
#  2023-10-04 15:42:49,701 [theorycollection] 'soliket.TheoryForge_MFLike' could not be found as internal, trying external.
#  2023-10-04 15:42:49,705 [theorycollection] 'soliket.Foreground' could not be found as internal, trying external.
#  2023-10-04 15:42:49,792 [theorycollection] 'soliket.BandPass' could not be found as internal, trying external.
#  2023-10-04 15:42:49,794 [likelihoodcollection] 'soliket.MFLike' could not be found as internal, trying external.
#  2023-10-04 15:42:50,447 [soliket.mflike] LAT_93_s0 LAT_93_s0 cl_00 (147,) 30 9000
#  2023-10-04 15:42:50,448 [soliket.mflike] LAT_93_s0 LAT_93_s2 cl_0e (147,) 30 9000
#  2023-10-04 15:42:50,449 [soliket.mflike] LAT_93_s2 LAT_93_s2 cl_ee (147,) 30 9000
#  2023-10-04 15:42:50,449 [soliket.mflike] LAT_93_s0 LAT_145_s0 cl_00 (147,) 30 9000
#  2023-10-04 15:42:50,450 [soliket.mflike] LAT_93_s0 LAT_145_s2 cl_0e (147,) 30 9000
#  2023-10-04 15:42:50,451 [soliket.mflike] LAT_93_s2 LAT_145_s0 cl_0e (147,) 30 9000
#  2023-10-04 15:42:50,452 [soliket.mflike] LAT_93_s2 LAT_145_s2 cl_ee (147,) 30 9000
#  2023-10-04 15:42:50,453 [soliket.mflike] LAT_93_s0 LAT_225_s0 cl_00 (147,) 30 9000
#  2023-10-04 15:42:50,453 [soliket.mflike] LAT_93_s0 LAT_225_s2 cl_0e (147,) 30 9000
#  2023-10-04 15:42:50,454 [soliket.mflike] LAT_93_s2 LAT_225_s0 cl_0e (147,) 30 9000
#  2023-10-04 15:42:50,455 [soliket.mflike] LAT_93_s2 LAT_225_s2 cl_ee (147,) 30 9000
#  2023-10-04 15:42:50,456 [soliket.mflike] LAT_145_s0 LAT_145_s0 cl_00 (147,) 30 9000
#  2023-10-04 15:42:50,457 [soliket.mflike] LAT_145_s0 LAT_145_s2 cl_0e (147,) 30 9000
#  2023-10-04 15:42:50,458 [soliket.mflike] LAT_145_s2 LAT_145_s2 cl_ee (147,) 30 9000
#  2023-10-04 15:42:50,459 [soliket.mflike] LAT_145_s0 LAT_225_s0 cl_00 (147,) 30 9000
#  2023-10-04 15:42:50,459 [soliket.mflike] LAT_145_s0 LAT_225_s2 cl_0e (147,) 30 9000
#  2023-10-04 15:42:50,460 [soliket.mflike] LAT_145_s2 LAT_225_s0 cl_0e (147,) 30 9000
#  2023-10-04 15:42:50,461 [soliket.mflike] LAT_145_s2 LAT_225_s2 cl_ee (147,) 30 9000
#  2023-10-04 15:42:50,462 [soliket.mflike] LAT_225_s0 LAT_225_s0 cl_00 (147,) 30 9000
#  2023-10-04 15:42:50,463 [soliket.mflike] LAT_225_s0 LAT_225_s2 cl_0e (147,) 30 9000
#  2023-10-04 15:42:50,463 [soliket.mflike] LAT_225_s2 LAT_225_s2 cl_ee (147,) 30 9000
#  2023-10-04 15:42:53,029 [soliket.mflike] Maximum multipole value: 9000
#  2023-10-04 15:42:53,031 [soliket.mflike] Initialized!
#  2023-10-04 15:42:53,058 [model] Parameters were assigned as follows:
#  2023-10-04 15:42:53,067 [model] - soliket.MFLike:
#  2023-10-04 15:42:53,070 [model]      Input:  []
#  2023-10-04 15:42:53,083 [model]      Output: []
#  2023-10-04 15:42:53,105 [model] - camb.transfers:
#  2023-10-04 15:42:53,121 [model]      Input:  ['cosmomc_theta', 'ombh2', 'omch2', 'Alens', 'tau', 'mnu', 'nnu']
#  2023-10-04 15:42:53,135 [model]      Output: []
#  2023-10-04 15:42:53,145 [model] - camb:
#  2023-10-04 15:42:53,151 [model]      Input:  ['As', 'ns']
#  2023-10-04 15:42:53,171 [model]      Output: []
#  2023-10-04 15:42:53,172 [model] - soliket.TheoryForge_MFLike:
#  2023-10-04 15:42:53,183 [model]      Input:  ['cal_LAT_93', 'cal_LAT_145', 'cal_LAT_225', 'calT_LAT_93', 'calE_LAT_93', 'calT_LAT_145', 'calE_LAT_145', 'calT_LAT_225', 'calE_LAT_225', 'calG_all', 'alpha_LAT_93', 'alpha_LAT_145', 'alpha_LAT_225']
#  2023-10-04 15:42:53,193 [model]      Output: []
#  2023-10-04 15:42:53,220 [model] - soliket.Foreground:
#  2023-10-04 15:42:53,228 [model]      Input:  ['a_tSZ', 'a_kSZ', 'a_p', 'beta_p', 'a_c', 'beta_c', 'a_s', 'a_gtt', 'a_gte', 'a_gee', 'a_psee', 'a_pste', 'xi', 'T_d']
#  2023-10-04 15:42:53,246 [model]      Output: []
#  2023-10-04 15:42:53,249 [model] - soliket.BandPass:
#  2023-10-04 15:42:53,251 [model]      Input:  ['bandint_shift_LAT_93', 'bandint_shift_LAT_145', 'bandint_shift_LAT_225']
#  2023-10-04 15:42:53,251 [model]      Output: []
#  2023-10-04 15:42:53,261 [model] Components will be computed in the order:
#  2023-10-04 15:42:53,262 [model]  - [camb.transfers, camb, soliket.BandPass, soliket.Foreground, soliket.TheoryForge_MFLike, soliket.MFLike]
#  2023-10-04 15:42:53,263 [model] Requirements will be calculated by these components:
#  2023-10-04 15:42:53,263 [model] - cmbfg_dict: soliket.TheoryForge_MFLike
#  2023-10-04 15:42:53,264 [model] - Cl: camb
#  2023-10-04 15:42:53,264 [model] - fg_dict: soliket.Foreground
#  2023-10-04 15:42:53,265 [model] - CAMB_transfers: camb.transfers
#  2023-10-04 15:42:53,266 [model] - bandint_freqs: soliket.BandPass

# %%
my_mflike = model.likelihood["soliket.MFLike"]
chi2 = -2 * (model.loglikes(fg_params)[0] - my_mflike.logp_const)
# Out:
#  2023-10-04 15:43:07,220 [model] Got input parameters: {'cosmomc_theta': 0.010409, 'logA': 3.045, 'As': 2.101003120287951e-09, 'ombh2': 0.02236, 'omch2': 0.1202, 'ns': 0.9649, 'Alens': 1.0, 'tau': 0.0544, 'mnu': 0.05866025403784439, 'nnu': 3.044, 'cal_LAT_93': 1.0, 'cal_LAT_145': 1.0, 'cal_LAT_225': 1.0, 'calT_LAT_93': 1.0, 'calE_LAT_93': 1.0, 'calT_LAT_145': 1.0, 'calE_LAT_145': 1.0, 'calT_LAT_225': 1.0, 'calE_LAT_225': 1.0, 'calG_all': 1.0, 'alpha_LAT_93': 0.0, 'alpha_LAT_145': 0.0, 'alpha_LAT_225': 0.0, 'a_tSZ': 3.3, 'a_kSZ': 1.6, 'a_p': 6.9, 'beta_p': 2.08, 'a_c': 4.9, 'beta_c': 2.2, 'a_s': 3.1, 'a_gtt': 2.81, 'a_gte': 0.1, 'a_gee': 0.1, 'a_psee': 0.0, 'a_pste': 0.0, 'xi': 0.2, 'T_d': 9.6, 'bandint_shift_LAT_93': 0.0, 'bandint_shift_LAT_145': 0.0, 'bandint_shift_LAT_225': 0.0}
#  2023-10-04 15:43:07,228 [camb.transfers] Got parameters {'cosmomc_theta': 0.010409, 'ombh2': 0.02236, 'omch2': 0.1202, 'Alens': 1.0, 'tau': 0.0544, 'mnu': 0.05866025403784439, 'nnu': 3.044}
#  2023-10-04 15:43:07,230 [camb.transfers] Computing new state
#  2023-10-04 15:43:07,230 [camb] Setting parameters: {'cosmomc_theta': 0.010409, 'ombh2': 0.02236, 'omch2': 0.1202, 'Alens': 1.0, 'tau': 0.0544, 'mnu': 0.05866025403784439, 'nnu': 3.044} and {'lens_potential_accuracy': 1, 'WantTransfer': True, 'Transfer.high_precision': True, 'Transfer.kmax': 1.2, 'num_nu_massless': 1.044, 'num_nu_massive': 2, 'nu_mass_eigenstates': 2, 'nu_mass_fractions': [0.14763410387308012, 0.8523658961269198], 'nu_mass_numbers': [1, 1], 'share_delta_neff': True, 'lmax': 9551}
#  2023-10-04 15:43:07,248 [camb] Setting attributes of CAMBparams: {'Want_CMB': True, 'Want_cl_2D_array': False, 'WantCls': True, 'NonLinear': 'NonLinear_lens'}
#  2023-10-04 15:43:07,702 [camb] Got parameters {'As': 2.101003120287951e-09, 'ns': 0.9649}
#  2023-10-04 15:43:07,703 [camb] Computing new state
#  2023-10-04 15:43:08,012 [soliket.bandpass] Got parameters {'bandint_shift_LAT_93': 0.0, 'bandint_shift_LAT_145': 0.0, 'bandint_shift_LAT_225': 0.0}
#  2023-10-04 15:43:08,013 [soliket.bandpass] Computing new state
#  2023-10-04 15:43:08,013 [soliket.foreground] Got parameters {'a_tSZ': 3.3, 'a_kSZ': 1.6, 'a_p': 6.9, 'beta_p': 2.08, 'a_c': 4.9, 'beta_c': 2.2, 'a_s': 3.1, 'a_gtt': 2.81, 'a_gte': 0.1, 'a_gee': 0.1, 'a_psee': 0.0, 'a_pste': 0.0, 'xi': 0.2, 'T_d': 9.6}
#  2023-10-04 15:43:08,013 [soliket.foreground] Computing new state
#  2023-10-04 15:43:08,014 [soliket.foreground] Computing bandpass at first step, no shifts
#  2023-10-04 15:43:08,019 [soliket.theoryforge_mflike] Got parameters {'cal_LAT_93': 1.0, 'cal_LAT_145': 1.0, 'cal_LAT_225': 1.0, 'calT_LAT_93': 1.0, 'calE_LAT_93': 1.0, 'calT_LAT_145': 1.0, 'calE_LAT_145': 1.0, 'calT_LAT_225': 1.0, 'calE_LAT_225': 1.0, 'calG_all': 1.0, 'alpha_LAT_93': 0.0, 'alpha_LAT_145': 0.0, 'alpha_LAT_225': 0.0}
#  2023-10-04 15:43:08,020 [soliket.theoryforge_mflike] Computing new state
#  2023-10-04 15:43:08,024 [soliket.mflike] Got parameters {}
#  2023-10-04 15:43:08,025 [soliket.mflike] Computing new state
#  2023-10-04 15:43:08,085 [soliket.mflike] Log-likelihood value computed = -10221.973477535827 (Χ² = 16367.582750352374)
#  2023-10-04 15:43:08,086 [soliket.mflike] Computed log-likelihood = -10222
#  2023-10-04 15:43:08,087 [model] Computed derived parameters: {'As': 2.101003120287951e-09}

# %% [markdown]
# Now use ```model.components[x].current_state[y]``` to get the corresponding spectra for the gievn set of cosmo+fg+nuisance params. In particular, we get the dictionary of cmb+fg spectra from TheoryForge_MFLike.

# %%
cmbfg=model.components[3].current_state["cmbfg_dict"]

# %% [markdown]
# Then, we use the function ```_get_power_spectra``` of ```MFLike``` to convolve the theory cmbfg spectra with the instrument nuisance and obtain the binned spectra to directly compare against data. We save the binned spectra in a dictionary ```ps_dic```

# %%
print(model.components[0].spec_meta[0]["t1"])
# Out:
# LAT_93

# %%
DlsObs = dict()
# Note we rescale l_bpws because cmbfg spectra start from l=2
ell = model.components[0].l_bpws - 2
ps_dic = {}

for m in model.components[0].spec_meta:
    p = m["pol"]
    i = m["ids"]
    w = m["bpw"].weight.T
    t1 = m["t1"]
    t2 = m["t2"]
    if(t1+"x"+t2 not in ps_dic.keys()):
        ps_dic[t1+"x"+t2]={"lbin": m["leff"]}

    if p in ['tt', 'ee', 'bb']:
        DlsObs[p,  m['t1'], m['t2']] = cmbfg[p, m['t1'], m['t2']][ell]
    else:  # ['te','tb','eb']
        if m['hasYX_xsp']:  # not symmetrizing
            DlsObs[p,  m['t1'], m['t2']] = cmbfg[p, m['t2'], m['t1']][ell]
        else:
            DlsObs[p,  m['t1'], m['t2']] = cmbfg[p, m['t1'], m['t2']][ell]
#
        if model.components[0].defaults['symmetrize']:  # we average TE and ET (as for data)
            DlsObs[p,  m['t1'], m['t2']] += cmbfg[p, m['t2'], m['t1']][ell]
            DlsObs[p,  m['t1'], m['t2']] *= 0.5

    clt = w @ DlsObs[p, m["t1"], m["t2"]]
    #print(t1+"x"+t2,p,clt)
    ps_dic[t1+"x"+t2].update({p: clt})

# %%
ps_dic.keys()
# Out:
# dict_keys(['LAT_93xLAT_93', 'LAT_93xLAT_145', 'LAT_93xLAT_225', 'LAT_145xLAT_145', 'LAT_145xLAT_225', 'LAT_225xLAT_225'])

# %% [markdown]
# We now save the spectra in the format needed by ```sacc```: lbin,TT,TE,TB,ET,BT,EE,EB,BE,BB

# %%
namedir="/Users/bradamante/Google Drive/My Drive/Work/Projects/Open/cobaya_packages/data/soliket_mflike/smooth_data/"
for k in ps_dic.keys():
    namefile = "Dl_"+k+"_auto_00000.dat"
    l = ps_dic[k]["lbin"]
    tt = ps_dic[k]["tt"]
    te = ps_dic[k]["te"]
    ee = ps_dic[k]["ee"]
    tbebbb = np.zeros(len(l))
    np.savetxt(namedir+namefile,np.column_stack((l,tt,te,tbebbb,te,tbebbb,ee,tbebbb,tbebbb,tbebbb)))

# %%
cltest=np.loadtxt(namedir+namefile)

# %%
cltest.shape
# Out:
# (147, 10)

# %% [markdown]
# We now use the routine in ``PSPype`` to convert the .txt data in sacc data. We first read the spectra:

# %%
data = {}
sim_suffix = "00000"
for spec_name in ps_dic.keys():
    na, nb = spec_name.split("x")
    data[na,nb] = {}
    spec = np.loadtxt("%s/Dl_%s_auto_%s.dat" % (namedir, spec_name, sim_suffix), unpack=True)
    ps = {"lbin": spec[0],
          "TT": spec[1],
          "TE": spec[2],
          "TB": spec[3],
          "ET": spec[4],
          "BT": spec[5],
          "EE": spec[6],
          "EB": spec[7],
          "BE": spec[8],
          "BB": spec[9]}
    data[na,nb] = ps

# %% [markdown]
# Then define useful functions

# %%
exp_freq = ['LAT_93', 'LAT_145', 'LAT_225']
pols = ["T", "E", "B"]
map_types = {"T": "0", "E": "e", "B": "b"}

def get_x_iterator():
    for id_efa, efa in enumerate(exp_freq):
        for id_efb, efb in enumerate(exp_freq):
            if (id_efa > id_efb): continue
            for ipa, pa in enumerate(pols):
                if (efa == efb):
                    polsb = pols[ipa:]
                else:
                    polsb = pols
                for pb in polsb:
                    yield (efa, efb, pa, pb)
                    print(efa, efb, pa, pb)

# %% [markdown]
# Import ```sacc``` and start adding info

# %%
import sacc

spec_sacc =  sacc.Sacc()

# %%
for exp_f in exp_freq:
    print("%s_s0" % (exp_f))

    my_data_bandpasses = {"nu":np.array([float(exp_f.split("_")[1])]), "b_nu":np.array([1.])}
    my_data_beams = {"l":np.arange(10000), "bl":np.ones(10000)}

    # CMB temperature 
    spec_sacc.add_tracer("NuMap", "%s_s0" % (exp_f),
                                 quantity="cmb_temperature", spin=0,
                                 nu=model.components[0].bands[exp_f+"_s0"]["nu"],
                                 bandpass=model.components[0].bands[exp_f+"_s0"]["bandpass"],
                                 ell=my_data_beams["l"],
                                 beam=my_data_beams["bl"])
    
    # CMB polarization
    spec_sacc.add_tracer("NuMap", "%s_s2" % (exp_f),
                                 quantity="cmb_polarization", spin=2,
                                 nu=model.components[0].bands[exp_f+"_s2"]["nu"],
                                 bandpass=model.components[0].bands[exp_f+"_s2"]["bandpass"],
                                 ell=my_data_beams["l"],
                                 beam=my_data_beams["bl"])
# Out:
# LAT_93_s0
# LAT_145_s0
# LAT_225_s0

# %% [markdown]
# Now add spectra to sacc object and save in fits format

# %%
for id_x, (efa, efb, pa, pb) in enumerate(get_x_iterator()):
    if pa == "T":
        ta_name = "%s_s0" % (efa)
    else:
        ta_name = "%s_s2" % (efa)

    if pb == "T":
        tb_name = "%s_s0" % (efb)
    else:
        tb_name = "%s_s2" % (efb)

    if pb == "T":
        cl_type = "cl_" + map_types[pb] + map_types[pa]
    else:
        cl_type = "cl_" + map_types[pa] + map_types[pb]

    lbin = data[efa, efb]["lbin"]
    cb = data[efa, efb][pa + pb]

    spec_sacc.add_ell_cl(cl_type, ta_name, tb_name, lbin, cb)
# Out:
# LAT_93 LAT_93 T T
# LAT_93 LAT_93 T E
# LAT_93 LAT_93 T B
# LAT_93 LAT_93 E E
# LAT_93 LAT_93 E B
# LAT_93 LAT_93 B B
# LAT_93 LAT_145 T T
# LAT_93 LAT_145 T E
# LAT_93 LAT_145 T B
# LAT_93 LAT_145 E T
# LAT_93 LAT_145 E E
# LAT_93 LAT_145 E B
# LAT_93 LAT_145 B T
# LAT_93 LAT_145 B E
# LAT_93 LAT_145 B B
# LAT_93 LAT_225 T T
# LAT_93 LAT_225 T E
# LAT_93 LAT_225 T B
# LAT_93 LAT_225 E T
# LAT_93 LAT_225 E E
# LAT_93 LAT_225 E B
# LAT_93 LAT_225 B T
# LAT_93 LAT_225 B E
# LAT_93 LAT_225 B B
# LAT_145 LAT_145 T T
# LAT_145 LAT_145 T E
# LAT_145 LAT_145 T B
# LAT_145 LAT_145 E E
# LAT_145 LAT_145 E B
# LAT_145 LAT_145 B B
# LAT_145 LAT_225 T T
# LAT_145 LAT_225 T E
# LAT_145 LAT_225 T B
# LAT_145 LAT_225 E T
# LAT_145 LAT_225 E E
# LAT_145 LAT_225 E B
# LAT_145 LAT_225 B T
# LAT_145 LAT_225 B E
# LAT_145 LAT_225 B B
# LAT_225 LAT_225 T T
# LAT_225 LAT_225 T E
# LAT_225 LAT_225 T B
# LAT_225 LAT_225 E E
# LAT_225 LAT_225 E B
# LAT_225 LAT_225 B B

# %%
spec_sacc.save_fits("%s/data_sacc_smooth_%s.fits" % (namedir, sim_suffix), overwrite=True)

# %% [markdown]
# # Test new data
#
# Let's read the newly created data and check that we get chi2=0 if compared against same fiducial

# %%
pre = "data_sacc_"
info = {
    "likelihood": {
        "soliket.MFLike": {
            "data_folder": namedir,
            "input_file": pre + "smooth_00000.fits",
            "cov_Bbl_file": packages_path+"data/MFLike/v0.8/data_sacc_w_covar_and_Bbl.fits",
            "defaults": {"polarizations": ['TT', 'TE', 'ET', 'EE'],
                         "scales": {"TT": [30, 9000],
                                    "TE": [30, 9000],
                                    "ET": [30, 9000],
                                    "EE": [30, 9000]},
                         "symmetrize": False
                        }
        }
    },
    "theory": {"camb": {"extra_args": {"lens_potential_accuracy": 1,
                                       "WantTransfer": True,
                                       "Transfer.high_precision": True,
                                       "Transfer.kmax": 1.2,
                                       "num_nu_massless": 1.044, #we use the minimal normal ordering case: massless lightest state, m2 and m3 computed according to oscilation measurements
                                       "num_nu_massive": 2, 
                                       "nu_mass_eigenstates": 2, 
                                       "nu_mass_fractions": [f2,f3],
                                       "nu_mass_numbers": [1,1],
                                       "share_delta_neff": True},
                        "stop_at_error": True}},
    "params": cosmo_params,
    "packages_path": packages_path,
    "debug": True,
}

# %%
namedir
# Out:
# '/Users/bradamante/Google Drive/My Drive/Work/Projects/Open/cobaya_packages/data/soliket_mflike/smooth_data/'

# %%
info["theory"]["soliket.TheoryForge_MFLike"] = {"spectra": {"polarizations": ["tt", "te", "ee"],
                                                            "lmin": 2,
                                                            "lmax": 9050},
                                                'stop_at_error': True}
info["theory"]["soliket.Foreground"] = {'stop_at_error': True}
info["theory"]["soliket.BandPass"] = {'stop_at_error': True}

# %%
from cobaya.model import get_model

model_test = get_model(info)
# Out:
#  2023-10-04 15:43:48,436 [input] 'soliket.TheoryForge_MFLike' could not be found as internal, trying external.
#  2023-10-04 15:43:48,447 [input] 'soliket.Foreground' could not be found as internal, trying external.
#  2023-10-04 15:43:48,456 [input] 'soliket.BandPass' could not be found as internal, trying external.
#  2023-10-04 15:43:48,460 [input] 'soliket.MFLike' could not be found as internal, trying external.
#  2023-10-04 15:43:48,478 [model] Input info updated with defaults (dumped to YAML):
# theory:
#   camb:
#     version: null
#     path: null
#     speed: 0.3
#     stop_at_error: true
#     extra_args:
#       lens_potential_accuracy: 1
#       WantTransfer: true
#       Transfer.high_precision: true
#       Transfer.kmax: 1.2
#       num_nu_massless: 1.044
#       num_nu_massive: 2
#       nu_mass_eigenstates: 2
#       nu_mass_fractions:
#       - 0.14763410387308012
#       - 0.8523658961269198
#       nu_mass_numbers:
#       - 1
#       - 1
#       share_delta_neff: true
#     ignore_obsolete: false
#     use_renames: false
#     external_primordial_pk: false
#     renames:
#       omegabh2: ombh2
#       omegach2: omch2
#       omegal: omega_de
#       omegak: omk
#       yhe: YHe
#       yheused: YHe
#       YpBBN: Y_p
#   soliket.TheoryForge_MFLike:
#     data_folder: MFLike/v0.6
#     exp_ch:
#     - LAT_93
#     - LAT_145
#     - LAT_225
#     eff_freqs:
#     - 93
#     - 145
#     - 225
#     spectra:
#       polarizations:
#       - tt
#       - te
#       - ee
#       lmin: 2
#       lmax: 9050
#     systematics_template: null
#     params:
#       cal_LAT_93:
#         value: 1
#         latex: \mathrm{Cal}_{\rm LAT}^{93}
#       cal_LAT_145:
#         value: 1
#         latex: \mathrm{Cal}_{\rm LAT}^{145}
#       cal_LAT_225:
#         value: 1
#         latex: \mathrm{Cal}_{\rm LAT}^{225}
#       calT_LAT_93:
#         value: 1
#         latex: \mathrm{Cal}_{\rm LAT, T}^{93}
#       calE_LAT_93:
#         value: 1
#         latex: \mathrm{Cal}_{\rm LAT, E}^{93}
#       calT_LAT_145:
#         value: 1
#         latex: \mathrm{Cal}_{\rm LAT, T}^{145}
#       calE_LAT_145:
#         value: 1
#         latex: \mathrm{Cal}_{\rm LAT, E}^{145}
#       calT_LAT_225:
#         value: 1
#         latex: \mathrm{Cal}_{\rm LAT, T}^{225}
#       calE_LAT_225:
#         value: 1
#         latex: \mathrm{Cal}_{\rm LAT, E}^{225}
#       calG_all:
#         value: 1
#         latex: \mathrm{Cal}_{\rm G}^{\rm All}
#       alpha_LAT_93:
#         value: 0
#         latex: \alpha_{\rm LAT}^{93}
#       alpha_LAT_145:
#         value: 0
#         latex: \alpha_{\rm LAT}^{145}
#       alpha_LAT_225:
#         value: 0
#         latex: \alpha_{\rm LAT}^{225}
#     speed: -1
#     stop_at_error: true
#     version: null
#   soliket.Foreground:
#     spectra:
#       polarizations:
#       - tt
#       - te
#       - ee
#       lmin: 2
#       lmax: 9000
#       exp_ch:
#       - LAT_150
#       eff_freqs:
#       - 150.0
#     foregrounds:
#       normalisation:
#         nu_0: 150.0
#         ell_0: 3000
#         T_CMB: 2.725
#       components:
#         tt:
#         - kSZ
#         - tSZ_and_CIB
#         - cibp
#         - dust
#         - radio
#         te:
#         - radio
#         - dust
#         ee:
#         - radio
#         - dust
#     params:
#       a_tSZ:
#         prior:
#           min: 3.0
#           max: 3.6
#         proposal: 0.05
#         latex: a_\mathrm{tSZ}
#       a_kSZ:
#         prior:
#           min: 1.4
#           max: 1.8
#         proposal: 0.1
#         latex: a_\mathrm{kSZ}
#       a_p:
#         prior:
#           min: 6.2
#           max: 7.6
#         proposal: 0.075
#         latex: a_p
#       beta_p:
#         prior:
#           min: 1.8
#           max: 2.2
#         proposal: 0.015
#         latex: \beta_p
#       a_c:
#         prior:
#           min: 4.4
#           max: 5.4
#         proposal: 0.12
#         latex: a_c
#       beta_c:
#         prior:
#           min: 2.0
#           max: 2.4
#         proposal: 0.03
#         latex: \beta_c
#       a_s:
#         prior:
#           min: 2.8
#           max: 3.4
#         proposal: 0.01
#         latex: a_s
#       a_gtt:
#         prior:
#           dist: norm
#           loc: 2.79
#           scale: 0.45
#         proposal: 0.4
#         latex: a_\mathrm{dust}^\mathrm{TT}
#       a_gte:
#         prior:
#           dist: norm
#           loc: 0.36
#           scale: 0.04
#         proposal: 0.04
#         latex: a_\mathrm{dust}^\mathrm{TE}
#       a_gee:
#         prior:
#           dist: norm
#           loc: 0.13
#           scale: 0.03
#         proposal: 0.03
#         latex: a_\mathrm{dust}^\mathrm{EE}
#       a_psee:
#         prior:
#           min: 0
#         proposal: 0.05
#         latex: a_\mathrm{ps}^\mathrm{EE}
#       a_pste:
#         prior:
#           min: -1
#           max: 1
#         proposal: 0.05
#         latex: a_\mathrm{ps}^\mathrm{TE}
#       xi:
#         prior:
#           min: 0
#           max: 0.2
#         proposal: 0.05
#         latex: \xi
#       T_d:
#         prior:
#           min: 8.6
#           max: 10.6
#         proposal: 0.6
#         latex: T_d
#     speed: -1
#     stop_at_error: true
#     version: null
#   soliket.BandPass:
#     data_folder: MFLike/v0.8
#     top_hat_band: null
#     external_bandpass: null
#     read_from_sacc: true
#     params:
#       bandint_shift_LAT_93:
#         value: 0
#         latex: \Delta_{\rm LAT}^{93}
#       bandint_shift_LAT_145:
#         value: 0
#         latex: \Delta_{\rm LAT}^{145}
#       bandint_shift_LAT_225:
#         value: 0
#         latex: \Delta_{\rm LAT}^{225}
#     speed: -1
#     stop_at_error: true
#     version: null
# likelihood:
#   soliket.MFLike:
#     data_folder: /Users/bradamante/Google Drive/My Drive/Work/Projects/Open/cobaya_packages/data/soliket_mflike/smooth_data/
#     input_file: data_sacc_smooth_00000.fits
#     cov_Bbl_file: /Users/bradamante/Google Drive/My Drive/Work/Projects/Open/cobaya_packages/data/MFLike/v0.8/data_sacc_w_covar_and_Bbl.fits
#     lmax_theory: null
#     defaults:
#       polarizations:
#       - TT
#       - TE
#       - ET
#       - EE
#       scales:
#         TT:
#         - 30
#         - 9000
#         TE:
#         - 30
#         - 9000
#         ET:
#         - 30
#         - 9000
#         EE:
#         - 30
#         - 9000
#       symmetrize: false
#     data:
#       experiments:
#       - LAT_93
#       - LAT_145
#       - LAT_225
#       spectra:
#       - experiments:
#         - LAT_93
#         - LAT_93
#       - experiments:
#         - LAT_93
#         - LAT_145
#       - experiments:
#         - LAT_93
#         - LAT_225
#       - experiments:
#         - LAT_145
#         - LAT_145
#       - experiments:
#         - LAT_145
#         - LAT_225
#       - experiments:
#         - LAT_225
#         - LAT_225
#     name: Gaussian
#     datapath: null
#     covpath: null
#     ncovsims: null
#     type: []
#     speed: -1
#     stop_at_error: false
#     version: null
# params:
#   cosmomc_theta:
#     value: 0.010409
#   logA:
#     value: 3.045
#     drop: true
#   As:
#     value: 'lambda logA: 1e-10*np.exp(logA)'
#     derived: true
#   ombh2:
#     value: 0.02236
#     renames:
#     - omegabh2
#   omch2:
#     value: 0.1202
#     renames:
#     - omegach2
#   ns:
#     value: 0.9649
#   Alens:
#     value: 1.0
#   tau:
#     value: 0.0544
#   mnu:
#     value: 0.05866025403784439
#   nnu:
#     value: 3.044
#   cal_LAT_93:
#     value: 1
#     latex: \mathrm{Cal}_{\rm LAT}^{93}
#   cal_LAT_145:
#     value: 1
#     latex: \mathrm{Cal}_{\rm LAT}^{145}
#   cal_LAT_225:
#     value: 1
#     latex: \mathrm{Cal}_{\rm LAT}^{225}
#   calT_LAT_93:
#     value: 1
#     latex: \mathrm{Cal}_{\rm LAT, T}^{93}
#   calE_LAT_93:
#     value: 1
#     latex: \mathrm{Cal}_{\rm LAT, E}^{93}
#   calT_LAT_145:
#     value: 1
#     latex: \mathrm{Cal}_{\rm LAT, T}^{145}
#   calE_LAT_145:
#     value: 1
#     latex: \mathrm{Cal}_{\rm LAT, E}^{145}
#   calT_LAT_225:
#     value: 1
#     latex: \mathrm{Cal}_{\rm LAT, T}^{225}
#   calE_LAT_225:
#     value: 1
#     latex: \mathrm{Cal}_{\rm LAT, E}^{225}
#   calG_all:
#     value: 1
#     latex: \mathrm{Cal}_{\rm G}^{\rm All}
#   alpha_LAT_93:
#     value: 0
#     latex: \alpha_{\rm LAT}^{93}
#   alpha_LAT_145:
#     value: 0
#     latex: \alpha_{\rm LAT}^{145}
#   alpha_LAT_225:
#     value: 0
#     latex: \alpha_{\rm LAT}^{225}
#   a_tSZ:
#     prior:
#       min: 3.0
#       max: 3.6
#     proposal: 0.05
#     latex: a_\mathrm{tSZ}
#   a_kSZ:
#     prior:
#       min: 1.4
#       max: 1.8
#     proposal: 0.1
#     latex: a_\mathrm{kSZ}
#   a_p:
#     prior:
#       min: 6.2
#       max: 7.6
#     proposal: 0.075
#     latex: a_p
#   beta_p:
#     prior:
#       min: 1.8
#       max: 2.2
#     proposal: 0.015
#     latex: \beta_p
#   a_c:
#     prior:
#       min: 4.4
#       max: 5.4
#     proposal: 0.12
#     latex: a_c
#   beta_c:
#     prior:
#       min: 2.0
#       max: 2.4
#     proposal: 0.03
#     latex: \beta_c
#   a_s:
#     prior:
#       min: 2.8
#       max: 3.4
#     proposal: 0.01
#     latex: a_s
#   a_gtt:
#     prior:
#       dist: norm
#       loc: 2.79
#       scale: 0.45
#     proposal: 0.4
#     latex: a_\mathrm{dust}^\mathrm{TT}
#   a_gte:
#     prior:
#       dist: norm
#       loc: 0.36
#       scale: 0.04
#     proposal: 0.04
#     latex: a_\mathrm{dust}^\mathrm{TE}
#   a_gee:
#     prior:
#       dist: norm
#       loc: 0.13
#       scale: 0.03
#     proposal: 0.03
#     latex: a_\mathrm{dust}^\mathrm{EE}
#   a_psee:
#     prior:
#       min: 0
#     proposal: 0.05
#     latex: a_\mathrm{ps}^\mathrm{EE}
#   a_pste:
#     prior:
#       min: -1
#       max: 1
#     proposal: 0.05
#     latex: a_\mathrm{ps}^\mathrm{TE}
#   xi:
#     prior:
#       min: 0
#       max: 0.2
#     proposal: 0.05
#     latex: \xi
#   T_d:
#     prior:
#       min: 8.6
#       max: 10.6
#     proposal: 0.6
#     latex: T_d
#   bandint_shift_LAT_93:
#     value: 0
#     latex: \Delta_{\rm LAT}^{93}
#   bandint_shift_LAT_145:
#     value: 0
#     latex: \Delta_{\rm LAT}^{145}
#   bandint_shift_LAT_225:
#     value: 0
#     latex: \Delta_{\rm LAT}^{225}
# packages_path: /Users/bradamante/Google Drive/My Drive/Work/Projects/Open/cobaya_packages/
# debug: true
#
#  2023-10-04 15:43:48,492 [camb] Attempting import of Cobaya-installed version, but defaulting to global import if not found.
#  2023-10-04 15:43:48,492 [camb] No (compiled) installation of 'camb' at /Users/bradamante/Library/CloudStorage/GoogleDrive-grbmtn@unife.it/My Drive/Work/Projects/Open/cobaya_packages/code/CAMB: Could not find compiled CAMB library camblib.so in /Users/bradamante/Library/CloudStorage/GoogleDrive-grbmtn@unife.it/My Drive/Work/Projects/Open/cobaya_packages/code/CAMB.
#  2023-10-04 15:43:48,492 [camb] Defaulting to global import.
#  2023-10-04 15:43:48,493 [camb] `camb` module loaded successfully from /Users/bradamante/miniconda/envs/soliket-tests/lib/python3.10/site-packages/camb
#  2023-10-04 15:43:48,495 [theorycollection] 'soliket.TheoryForge_MFLike' could not be found as internal, trying external.
#  2023-10-04 15:43:48,499 [theorycollection] 'soliket.Foreground' could not be found as internal, trying external.
#  2023-10-04 15:43:48,583 [theorycollection] 'soliket.BandPass' could not be found as internal, trying external.
#  2023-10-04 15:43:48,586 [likelihoodcollection] 'soliket.MFLike' could not be found as internal, trying external.
#  2023-10-04 15:43:49,183 [soliket.mflike] LAT_93_s0 LAT_93_s0 cl_00 (147,) 30 9000
#  2023-10-04 15:43:49,184 [soliket.mflike] LAT_93_s0 LAT_93_s2 cl_0e (147,) 30 9000
#  2023-10-04 15:43:49,185 [soliket.mflike] LAT_93_s2 LAT_93_s2 cl_ee (147,) 30 9000
#  2023-10-04 15:43:49,186 [soliket.mflike] LAT_93_s0 LAT_145_s0 cl_00 (147,) 30 9000
#  2023-10-04 15:43:49,187 [soliket.mflike] LAT_93_s0 LAT_145_s2 cl_0e (147,) 30 9000
#  2023-10-04 15:43:49,188 [soliket.mflike] LAT_93_s2 LAT_145_s0 cl_0e (147,) 30 9000
#  2023-10-04 15:43:49,189 [soliket.mflike] LAT_93_s2 LAT_145_s2 cl_ee (147,) 30 9000
#  2023-10-04 15:43:49,190 [soliket.mflike] LAT_93_s0 LAT_225_s0 cl_00 (147,) 30 9000
#  2023-10-04 15:43:49,192 [soliket.mflike] LAT_93_s0 LAT_225_s2 cl_0e (147,) 30 9000
#  2023-10-04 15:43:49,193 [soliket.mflike] LAT_93_s2 LAT_225_s0 cl_0e (147,) 30 9000
#  2023-10-04 15:43:49,194 [soliket.mflike] LAT_93_s2 LAT_225_s2 cl_ee (147,) 30 9000
#  2023-10-04 15:43:49,195 [soliket.mflike] LAT_145_s0 LAT_145_s0 cl_00 (147,) 30 9000
#  2023-10-04 15:43:49,196 [soliket.mflike] LAT_145_s0 LAT_145_s2 cl_0e (147,) 30 9000
#  2023-10-04 15:43:49,197 [soliket.mflike] LAT_145_s2 LAT_145_s2 cl_ee (147,) 30 9000
#  2023-10-04 15:43:49,199 [soliket.mflike] LAT_145_s0 LAT_225_s0 cl_00 (147,) 30 9000
#  2023-10-04 15:43:49,200 [soliket.mflike] LAT_145_s0 LAT_225_s2 cl_0e (147,) 30 9000
#  2023-10-04 15:43:49,201 [soliket.mflike] LAT_145_s2 LAT_225_s0 cl_0e (147,) 30 9000
#  2023-10-04 15:43:49,202 [soliket.mflike] LAT_145_s2 LAT_225_s2 cl_ee (147,) 30 9000
#  2023-10-04 15:43:49,203 [soliket.mflike] LAT_225_s0 LAT_225_s0 cl_00 (147,) 30 9000
#  2023-10-04 15:43:49,204 [soliket.mflike] LAT_225_s0 LAT_225_s2 cl_0e (147,) 30 9000
#  2023-10-04 15:43:49,205 [soliket.mflike] LAT_225_s2 LAT_225_s2 cl_ee (147,) 30 9000
#  2023-10-04 15:43:51,919 [soliket.mflike] Maximum multipole value: 9000
#  2023-10-04 15:43:51,920 [soliket.mflike] Initialized!
#  2023-10-04 15:43:51,925 [model] Parameters were assigned as follows:
#  2023-10-04 15:43:51,951 [model] - soliket.MFLike:
#  2023-10-04 15:43:51,967 [model]      Input:  []
#  2023-10-04 15:43:51,973 [model]      Output: []
#  2023-10-04 15:43:51,976 [model] - camb.transfers:
#  2023-10-04 15:43:51,976 [model]      Input:  ['cosmomc_theta', 'ombh2', 'omch2', 'Alens', 'tau', 'mnu', 'nnu']
#  2023-10-04 15:43:51,977 [model]      Output: []
#  2023-10-04 15:43:51,979 [model] - camb:
#  2023-10-04 15:43:51,980 [model]      Input:  ['As', 'ns']
#  2023-10-04 15:43:51,980 [model]      Output: []
#  2023-10-04 15:43:51,981 [model] - soliket.TheoryForge_MFLike:
#  2023-10-04 15:43:51,982 [model]      Input:  ['cal_LAT_93', 'cal_LAT_145', 'cal_LAT_225', 'calT_LAT_93', 'calE_LAT_93', 'calT_LAT_145', 'calE_LAT_145', 'calT_LAT_225', 'calE_LAT_225', 'calG_all', 'alpha_LAT_93', 'alpha_LAT_145', 'alpha_LAT_225']
#  2023-10-04 15:43:51,983 [model]      Output: []
#  2023-10-04 15:43:51,984 [model] - soliket.Foreground:
#  2023-10-04 15:43:51,984 [model]      Input:  ['a_tSZ', 'a_kSZ', 'a_p', 'beta_p', 'a_c', 'beta_c', 'a_s', 'a_gtt', 'a_gte', 'a_gee', 'a_psee', 'a_pste', 'xi', 'T_d']
#  2023-10-04 15:43:51,985 [model]      Output: []
#  2023-10-04 15:43:51,985 [model] - soliket.BandPass:
#  2023-10-04 15:43:51,986 [model]      Input:  ['bandint_shift_LAT_93', 'bandint_shift_LAT_145', 'bandint_shift_LAT_225']
#  2023-10-04 15:43:51,987 [model]      Output: []
#  2023-10-04 15:43:51,992 [model] Components will be computed in the order:
#  2023-10-04 15:43:51,993 [model]  - [camb.transfers, camb, soliket.BandPass, soliket.Foreground, soliket.TheoryForge_MFLike, soliket.MFLike]
#  2023-10-04 15:43:51,994 [model] Requirements will be calculated by these components:
#  2023-10-04 15:43:51,995 [model] - cmbfg_dict: soliket.TheoryForge_MFLike
#  2023-10-04 15:43:51,995 [model] - Cl: camb
#  2023-10-04 15:43:51,996 [model] - fg_dict: soliket.Foreground
#  2023-10-04 15:43:51,996 [model] - CAMB_transfers: camb.transfers
#  2023-10-04 15:43:51,998 [model] - bandint_freqs: soliket.BandPass

# %%
my_mflike = model_test.likelihood["soliket.MFLike"]
chi2 = -2 * (model_test.loglikes(fg_params)[0] - my_mflike.logp_const)
# Out:
#  2023-10-04 15:44:15,740 [model] Got input parameters: {'cosmomc_theta': 0.010409, 'logA': 3.045, 'As': 2.101003120287951e-09, 'ombh2': 0.02236, 'omch2': 0.1202, 'ns': 0.9649, 'Alens': 1.0, 'tau': 0.0544, 'mnu': 0.05866025403784439, 'nnu': 3.044, 'cal_LAT_93': 1.0, 'cal_LAT_145': 1.0, 'cal_LAT_225': 1.0, 'calT_LAT_93': 1.0, 'calE_LAT_93': 1.0, 'calT_LAT_145': 1.0, 'calE_LAT_145': 1.0, 'calT_LAT_225': 1.0, 'calE_LAT_225': 1.0, 'calG_all': 1.0, 'alpha_LAT_93': 0.0, 'alpha_LAT_145': 0.0, 'alpha_LAT_225': 0.0, 'a_tSZ': 3.3, 'a_kSZ': 1.6, 'a_p': 6.9, 'beta_p': 2.08, 'a_c': 4.9, 'beta_c': 2.2, 'a_s': 3.1, 'a_gtt': 2.81, 'a_gte': 0.1, 'a_gee': 0.1, 'a_psee': 0.0, 'a_pste': 0.0, 'xi': 0.2, 'T_d': 9.6, 'bandint_shift_LAT_93': 0.0, 'bandint_shift_LAT_145': 0.0, 'bandint_shift_LAT_225': 0.0}
#  2023-10-04 15:44:15,748 [camb.transfers] Got parameters {'cosmomc_theta': 0.010409, 'ombh2': 0.02236, 'omch2': 0.1202, 'Alens': 1.0, 'tau': 0.0544, 'mnu': 0.05866025403784439, 'nnu': 3.044}
#  2023-10-04 15:44:15,751 [camb.transfers] Computing new state
#  2023-10-04 15:44:15,752 [camb] Setting parameters: {'cosmomc_theta': 0.010409, 'ombh2': 0.02236, 'omch2': 0.1202, 'Alens': 1.0, 'tau': 0.0544, 'mnu': 0.05866025403784439, 'nnu': 3.044} and {'lens_potential_accuracy': 1, 'WantTransfer': True, 'Transfer.high_precision': True, 'Transfer.kmax': 1.2, 'num_nu_massless': 1.044, 'num_nu_massive': 2, 'nu_mass_eigenstates': 2, 'nu_mass_fractions': [0.14763410387308012, 0.8523658961269198], 'nu_mass_numbers': [1, 1], 'share_delta_neff': True, 'lmax': 9551}
#  2023-10-04 15:44:15,761 [camb] Setting attributes of CAMBparams: {'Want_CMB': True, 'Want_cl_2D_array': False, 'WantCls': True, 'NonLinear': 'NonLinear_lens'}
#  2023-10-04 15:44:16,220 [camb] Got parameters {'As': 2.101003120287951e-09, 'ns': 0.9649}
#  2023-10-04 15:44:16,221 [camb] Computing new state
#  2023-10-04 15:44:16,492 [soliket.bandpass] Got parameters {'bandint_shift_LAT_93': 0.0, 'bandint_shift_LAT_145': 0.0, 'bandint_shift_LAT_225': 0.0}
#  2023-10-04 15:44:16,492 [soliket.bandpass] Computing new state
#  2023-10-04 15:44:16,493 [soliket.foreground] Got parameters {'a_tSZ': 3.3, 'a_kSZ': 1.6, 'a_p': 6.9, 'beta_p': 2.08, 'a_c': 4.9, 'beta_c': 2.2, 'a_s': 3.1, 'a_gtt': 2.81, 'a_gte': 0.1, 'a_gee': 0.1, 'a_psee': 0.0, 'a_pste': 0.0, 'xi': 0.2, 'T_d': 9.6}
#  2023-10-04 15:44:16,493 [soliket.foreground] Computing new state
#  2023-10-04 15:44:16,493 [soliket.foreground] Computing bandpass at first step, no shifts
#  2023-10-04 15:44:16,498 [soliket.theoryforge_mflike] Got parameters {'cal_LAT_93': 1.0, 'cal_LAT_145': 1.0, 'cal_LAT_225': 1.0, 'calT_LAT_93': 1.0, 'calE_LAT_93': 1.0, 'calT_LAT_145': 1.0, 'calE_LAT_145': 1.0, 'calT_LAT_225': 1.0, 'calE_LAT_225': 1.0, 'calG_all': 1.0, 'alpha_LAT_93': 0.0, 'alpha_LAT_145': 0.0, 'alpha_LAT_225': 0.0}
#  2023-10-04 15:44:16,499 [soliket.theoryforge_mflike] Computing new state
#  2023-10-04 15:44:16,501 [soliket.mflike] Got parameters {}
#  2023-10-04 15:44:16,501 [soliket.mflike] Computing new state
#  2023-10-04 15:44:16,580 [soliket.mflike] Log-likelihood value computed = -2038.1821023596394 (Χ² = -0.0)
#  2023-10-04 15:44:16,583 [soliket.mflike] Computed log-likelihood = -2038.18
#  2023-10-04 15:44:16,585 [model] Computed derived parameters: {'As': 2.101003120287951e-09}

# %%
chi2
# Out:
# array([-0.])

# %% [markdown]
# Awesome!!!
