# %% [markdown]
# # Create a smooth fiducial for SOLikeT/MFLike
#
# In this notebook, we generate a fiducial smooth (i.e., binned spectrum-based theoretical prediction, no map-based random realization) dataset. We start from cmb+fg spectra (MFLike).

# %%
# %matplotlib inline
import os
import tempfile

import camb
import cobaya
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

print("     Numpy :", np.__version__)
print("Matplotlib :", mpl.__version__)
print("      CAMB :", camb.__version__)
print("    Cobaya :", cobaya.__version__)
# Out:
#      Numpy : 1.24.3
# Matplotlib : 3.8.0
#       CAMB : 1.5.0
#     Cobaya : 3.5.4

# %%
# Fiducial cosmo params. When used in a MCMC, the smooth data must agree with this input values

# set neutrino masses
m1=0
m2=np.sqrt(7.5e-5)
m3=np.sqrt(2.5e-3)

sumnu=m1+m2+m3

f1=m1/sumnu
f2=m2/sumnu
f3=m3/sumnu

print('sumnu =', sumnu)
print('')
print('f1 =', f1, '\nf2 =', f2, '\nf3 =', f3)

cosmo_params = {
    "cosmomc_theta": 0.0104090,
    "logA": {"value": 3.045, "drop": True},
    "As": {"value": "lambda logA: 1e-10*np.exp(logA)"},
    "ombh2": 0.02236,
    "omch2": 0.1202,
    "ns": 0.9649,
    "Alens": 1.0,
    "tau": 0.0544,
    "mnu": sumnu,
    "nnu": 3.044,
}

fg_params = {
    "a_tSZ": 3.30,
    "a_kSZ": 1.60,
    "a_p": 6.90,
    "beta_p": 2.08,
    "a_c": 4.90,
    "beta_c": 2.20,
    "a_s": 3.10,
    "T_d": 9.60,
    "a_gtt": 2.81,
    "a_gte": 0.10,
    "a_gee": 0.10,
    "a_psee": 0.000,
    "a_pste": 0.000,
    "xi": 0.20,
}

nuisance_params = {
    "bandint_shift_93": 0,  # only ideal values for now
    "bandint_shift_145": 0,
    "bandint_shift_225": 0,
    "cal_LAT_93": 1,
    "cal_LAT_145": 1,
    "cal_LAT_225": 1,
    "calT_LAT_93": 1,
    "calT_LAT_145": 1,
    "calT_LAT_225": 1,
    "calE_LAT_93": 1,
    "calE_LAT_145": 1,
    "calE_LAT_225": 1,
    "calG_all": 1,
    "alpha_LAT_93": 0,
    "alpha_LAT_145": 0,
    "alpha_LAT_225": 0,
}
# Out:
# sumnu = 0.05866025403784439
#
# f1 = 0.0
# f2 = 0.14763410387308012
# f3 = 0.8523658961269198

# %% [markdown]
# Let's use SOLikeT/MFLike to generate the fiducial spectra

# %%
packages_path = "/Users/bradamante/Library/CloudStorage/GoogleDrive-grbmtn@unife.it/My Drive/Work/Projects/Open/cobaya_packages"

# %%
pre = "LAT_simu_sacc_"
info = {
    "likelihood": {
    "mflike.TTTEEE": {
        "package_install": "pip",
        "data_folder": "MFLike/v0.8",
        "input_file": pre + "00000.fits",
        "cov_Bbl_file": "data_sacc_w_covar_and_Bbl.fits",
        "defaults": {"polarizations": ["TT","TE","ET","EE"],
                     "scales": {"TT": [30, 9000],
                                "TE": [30, 9000],
                                "ET": [30, 9000],
                                "EE": [30, 9000]},
                     "symmetrize": False
                    },
    }
},
        "theory": {"camb": {"extra_args": {"lens_potential_accuracy": 1,
                                           "WantTransfer": True,
                                           "Transfer.high_precision": True,
                                           "Transfer.kmax": 1.2,
                                           "num_nu_massless": 1.044, #we use the minimal normal ordering case: massless lightest state, m2 and m3
                                           "num_nu_massive": 2,
                                           "nu_mass_eigenstates": 2,
                                           "nu_mass_fractions": [f2,f3],
                                           "nu_mass_numbers": [1,1],
                                           "share_delta_neff": False},
                            "stop_at_error": True}},
        "params": cosmo_params,
        "packages_path": packages_path,
        "debug": True,
}

# %%
info["theory"]["mflike.BandpowerForeground"] = {'stop_at_error': True}

# %%
from cobaya.model import get_model

model = get_model(info)
# Out:
#  2025-03-11 15:06:53,203 [input] 'mflike.BandpowerForeground' could not be found as internal, trying external.
#  2025-03-11 15:06:53,669 [input] 'mflike.TTTEEE' could not be found as internal, trying external.
#  2025-03-11 15:06:53,687 [model] Input info updated with defaults (dumped to YAML):
# theory:
#   camb:
#     version: null
#     path: null
#     speed: 0.3
#     stop_at_error: true
#     extra_args:
#       lens_potential_accuracy: 1
#       WantTransfer: true
#       Transfer.high_precision: true
#       Transfer.kmax: 1.2
#       num_nu_massless: 1.044
#       num_nu_massive: 2
#       nu_mass_eigenstates: 2
#       nu_mass_fractions:
#       - 0.14763410387308012
#       - 0.8523658961269198
#       nu_mass_numbers:
#       - 1
#       - 1
#       share_delta_neff: false
#     ignore_obsolete: false
#     use_renames: false
#     external_primordial_pk: false
#     renames:
#       omegabh2: ombh2
#       omegach2: omch2
#       omegal: omega_de
#       omegak: omk
#       yhe: YHe
#       yheused: YHe
#       YpBBN: Y_p
#   mflike.BandpowerForeground:
#     top_hat_band: null
#     bands: null
#     beams: null
#     beam_profile: null
#     requested_cls:
#     - tt
#     - te
#     - ee
#     lmin: 2
#     lmax: 6001
#     ells: null
#     experiments:
#     - LAT_93
#     - LAT_145
#     - LAT_225
#     bandint_freqs:
#     - 93.0
#     - 145.0
#     - 225.0
#     normalisation:
#       nu_0: 150.0
#       ell_0: 3000
#       T_CMB: 2.725
#     components:
#       tt:
#       - kSZ
#       - tSZ_and_CIB
#       - cibp
#       - dust
#       - radio
#       te:
#       - radio
#       - dust
#       ee:
#       - radio
#       - dust
#     params:
#       beta_s:
#         value: -2.5
#         latex: \beta_s
#       alpha_s:
#         value: 1.0
#         latex: \alpha_s
#       T_effd:
#         value: 19.6
#         latex: T_{\mathrm{dust},\mathrm{eff}}
#       beta_d:
#         value: 1.5
#         latex: \beta_\mathrm{dust}
#       a_tSZ:
#         prior:
#           min: 3.0
#           max: 3.6
#         proposal: 0.05
#         latex: a_\mathrm{tSZ}
#       a_kSZ:
#         prior:
#           min: 1.4
#           max: 1.8
#         proposal: 0.1
#         latex: a_\mathrm{kSZ}
#       a_p:
#         prior:
#           min: 6.2
#           max: 7.6
#         proposal: 0.075
#         latex: a_p
#       beta_p:
#         prior:
#           min: 1.8
#           max: 2.2
#         proposal: 0.015
#         latex: \beta_p
#       a_c:
#         prior:
#           min: 4.4
#           max: 5.4
#         proposal: 0.12
#         latex: a_c
#       beta_c:
#         prior:
#           min: 2.0
#           max: 2.4
#         proposal: 0.03
#         latex: \beta_c
#       a_s:
#         prior:
#           min: 2.8
#           max: 3.4
#         proposal: 0.01
#         latex: a_s
#       a_gtt:
#         prior:
#           dist: norm
#           loc: 2.79
#           scale: 0.45
#         proposal: 0.4
#         latex: a_\mathrm{dust}^\mathrm{TT}
#       xi:
#         prior:
#           min: 0
#           max: 0.2
#         proposal: 0.05
#         latex: \xi
#       T_d:
#         prior:
#           min: 8.6
#           max: 10.6
#         proposal: 0.6
#         latex: T_d
#       alpha_dT:
#         value: -0.6
#         latex: \alpha_{\mathrm{dust},T}
#       alpha_p:
#         value: 1.0
#         latex: \alpha_p
#       alpha_tSZ:
#         value: 0.0
#         latex: \alpha_{\rm tSZ}
#       a_gte:
#         prior:
#           dist: norm
#           loc: 0.36
#           scale: 0.04
#         proposal: 0.04
#         latex: a_\mathrm{dust}^\mathrm{TE}
#       a_pste:
#         prior:
#           min: -1
#           max: 1
#         proposal: 0.05
#         latex: a_\mathrm{ps}^\mathrm{TE}
#       alpha_dE:
#         value: -0.4
#         latex: \alpha_{\mathrm{dust},E}
#       a_gee:
#         prior:
#           dist: norm
#           loc: 0.13
#           scale: 0.03
#         proposal: 0.03
#         latex: a_\mathrm{dust}^\mathrm{EE}
#       a_psee:
#         prior:
#           min: 0
#         proposal: 0.05
#         latex: a_\mathrm{ps}^\mathrm{EE}
#     speed: -1
#     stop_at_error: true
#     version: null
# likelihood:
#   mflike.TTTEEE:
#     requested_cls:
#     - tt
#     - te
#     - ee
#     defaults:
#       polarizations:
#       - TT
#       - TE
#       - ET
#       - EE
#       scales:
#         TT:
#         - 30
#         - 9000
#         TE:
#         - 30
#         - 9000
#         ET:
#         - 30
#         - 9000
#         EE:
#         - 30
#         - 9000
#       symmetrize: false
#     params:
#       cal_LAT_93:
#         value: 1
#         latex: \mathrm{Cal}^{93}
#       cal_LAT_145:
#         value: 1
#         latex: \mathrm{Cal}^{145}
#       cal_LAT_225:
#         value: 1
#         latex: \mathrm{Cal}^{225}
#       calG_all:
#         value: 1
#         latex: \mathrm{Cal}_{\rm G}^{\rm All}
#       alpha_LAT_93:
#         value: 0
#         latex: \alpha^{93}
#       alpha_LAT_145:
#         value: 0
#         latex: \alpha^{145}
#       alpha_LAT_225:
#         value: 0
#         latex: \alpha^{225}
#       bandint_shift_LAT_93:
#         value: 0
#         latex: \Delta_{\rm band}^{93}
#       bandint_shift_LAT_145:
#         value: 0
#         latex: \Delta_{\rm band}^{145}
#       bandint_shift_LAT_225:
#         value: 0
#         latex: \Delta_{\rm band}^{225}
#       calT_LAT_93:
#         value: 1
#         latex: \mathrm{Cal}_{\rm T}^{93}
#       calT_LAT_145:
#         value: 1
#         latex: \mathrm{Cal}_{\rm T}^{145}
#       calT_LAT_225:
#         value: 1
#         latex: \mathrm{Cal}_{\rm T}^{225}
#       calE_LAT_93:
#         value: 1
#         latex: \mathrm{Cal}_{\rm E}^{93}
#       calE_LAT_145:
#         value: 1
#         latex: \mathrm{Cal}_{\rm E}^{145}
#       calE_LAT_225:
#         value: 1
#         latex: \mathrm{Cal}_{\rm E}^{225}
#     data_folder: MFLike/v0.8
#     input_file: LAT_simu_sacc_00000.fits
#     cov_Bbl_file: data_sacc_w_covar_and_Bbl.fits
#     lmax_theory: null
#     data:
#       experiments:
#       - LAT_93
#       - LAT_145
#       - LAT_225
#       spectra:
#       - experiments:
#         - LAT_93
#         - LAT_93
#       - experiments:
#         - LAT_93
#         - LAT_145
#       - experiments:
#         - LAT_93
#         - LAT_225
#       - experiments:
#         - LAT_145
#         - LAT_145
#       - experiments:
#         - LAT_145
#         - LAT_225
#       - experiments:
#         - LAT_225
#         - LAT_225
#     systematics_template: null
#     type: []
#     speed: -1
#     stop_at_error: false
#     version: null
#     package_install: pip
# params:
#   cosmomc_theta:
#     value: 0.010409
#   logA:
#     value: 3.045
#     drop: true
#   As:
#     value: 'lambda logA: 1e-10*np.exp(logA)'
#     derived: true
#   ombh2:
#     value: 0.02236
#     renames:
#     - omegabh2
#   omch2:
#     value: 0.1202
#     renames:
#     - omegach2
#   ns:
#     value: 0.9649
#   Alens:
#     value: 1.0
#   tau:
#     value: 0.0544
#   mnu:
#     value: 0.05866025403784439
#   nnu:
#     value: 3.044
#   beta_s:
#     value: -2.5
#     latex: \beta_s
#   alpha_s:
#     value: 1.0
#     latex: \alpha_s
#   T_effd:
#     value: 19.6
#     latex: T_{\mathrm{dust},\mathrm{eff}}
#   beta_d:
#     value: 1.5
#     latex: \beta_\mathrm{dust}
#   a_tSZ:
#     prior:
#       min: 3.0
#       max: 3.6
#     proposal: 0.05
#     latex: a_\mathrm{tSZ}
#   a_kSZ:
#     prior:
#       min: 1.4
#       max: 1.8
#     proposal: 0.1
#     latex: a_\mathrm{kSZ}
#   a_p:
#     prior:
#       min: 6.2
#       max: 7.6
#     proposal: 0.075
#     latex: a_p
#   beta_p:
#     prior:
#       min: 1.8
#       max: 2.2
#     proposal: 0.015
#     latex: \beta_p
#   a_c:
#     prior:
#       min: 4.4
#       max: 5.4
#     proposal: 0.12
#     latex: a_c
#   beta_c:
#     prior:
#       min: 2.0
#       max: 2.4
#     proposal: 0.03
#     latex: \beta_c
#   a_s:
#     prior:
#       min: 2.8
#       max: 3.4
#     proposal: 0.01
#     latex: a_s
#   a_gtt:
#     prior:
#       dist: norm
#       loc: 2.79
#       scale: 0.45
#     proposal: 0.4
#     latex: a_\mathrm{dust}^\mathrm{TT}
#   xi:
#     prior:
#       min: 0
#       max: 0.2
#     proposal: 0.05
#     latex: \xi
#   T_d:
#     prior:
#       min: 8.6
#       max: 10.6
#     proposal: 0.6
#     latex: T_d
#   alpha_dT:
#     value: -0.6
#     latex: \alpha_{\mathrm{dust},T}
#   alpha_p:
#     value: 1.0
#     latex: \alpha_p
#   alpha_tSZ:
#     value: 0.0
#     latex: \alpha_{\rm tSZ}
#   a_gte:
#     prior:
#       dist: norm
#       loc: 0.36
#       scale: 0.04
#     proposal: 0.04
#     latex: a_\mathrm{dust}^\mathrm{TE}
#   a_pste:
#     prior:
#       min: -1
#       max: 1
#     proposal: 0.05
#     latex: a_\mathrm{ps}^\mathrm{TE}
#   alpha_dE:
#     value: -0.4
#     latex: \alpha_{\mathrm{dust},E}
#   a_gee:
#     prior:
#       dist: norm
#       loc: 0.13
#       scale: 0.03
#     proposal: 0.03
#     latex: a_\mathrm{dust}^\mathrm{EE}
#   a_psee:
#     prior:
#       min: 0
#     proposal: 0.05
#     latex: a_\mathrm{ps}^\mathrm{EE}
#   cal_LAT_93:
#     value: 1
#     latex: \mathrm{Cal}^{93}
#   cal_LAT_145:
#     value: 1
#     latex: \mathrm{Cal}^{145}
#   cal_LAT_225:
#     value: 1
#     latex: \mathrm{Cal}^{225}
#   calG_all:
#     value: 1
#     latex: \mathrm{Cal}_{\rm G}^{\rm All}
#   alpha_LAT_93:
#     value: 0
#     latex: \alpha^{93}
#   alpha_LAT_145:
#     value: 0
#     latex: \alpha^{145}
#   alpha_LAT_225:
#     value: 0
#     latex: \alpha^{225}
#   bandint_shift_LAT_93:
#     value: 0
#     latex: \Delta_{\rm band}^{93}
#   bandint_shift_LAT_145:
#     value: 0
#     latex: \Delta_{\rm band}^{145}
#   bandint_shift_LAT_225:
#     value: 0
#     latex: \Delta_{\rm band}^{225}
#   calT_LAT_93:
#     value: 1
#     latex: \mathrm{Cal}_{\rm T}^{93}
#   calT_LAT_145:
#     value: 1
#     latex: \mathrm{Cal}_{\rm T}^{145}
#   calT_LAT_225:
#     value: 1
#     latex: \mathrm{Cal}_{\rm T}^{225}
#   calE_LAT_93:
#     value: 1
#     latex: \mathrm{Cal}_{\rm E}^{93}
#   calE_LAT_145:
#     value: 1
#     latex: \mathrm{Cal}_{\rm E}^{145}
#   calE_LAT_225:
#     value: 1
#     latex: \mathrm{Cal}_{\rm E}^{225}
# packages_path: /Users/bradamante/Library/CloudStorage/GoogleDrive-grbmtn@unife.it/My
#   Drive/Work/Projects/Open/cobaya_packages
# debug: true
#
#  2025-03-11 15:06:53,697 [camb] Attempting import of Cobaya-installed version, but defaulting to global import if not found.
#  2025-03-11 15:06:53,698 [camb] 'camb' to be imported from (sub)directory /Users/bradamante/Library/CloudStorage/GoogleDrive-grbmtn@unife.it/My Drive/Work/Projects/Open/cobaya_packages/code/CAMB
#  2025-03-11 15:06:53,699 [camb] Could not import 'camb' from /Users/bradamante/Library/CloudStorage/GoogleDrive-grbmtn@unife.it/My Drive/Work/Projects/Open/cobaya_packages/code/CAMB: Module camb successfully loaded, but not from requested path: /Users/bradamante/Library/CloudStorage/GoogleDrive-grbmtn@unife.it/My Drive/Work/Projects/Open/cobaya_packages/code/CAMB, but instead from /Users/bradamante/miniconda/envs/soliket-tests/lib/python3.10/site-packages/camb
#  2025-03-11 15:06:53,699 [camb] Defaulting to global import.
#  2025-03-11 15:06:53,700 [camb] `camb` module loaded successfully from /Users/bradamante/miniconda/envs/soliket-tests/lib/python3.10/site-packages/camb
#  2025-03-11 15:06:53,701 [theorycollection] 'mflike.BandpowerForeground' could not be found as internal, trying external.
#  2025-03-11 15:06:53,783 [likelihoodcollection] 'mflike.TTTEEE' could not be found as internal, trying external.
#  2025-03-11 15:06:53,795 [h5py._conv] Creating converter from 7 to 5
#  2025-03-11 15:06:53,795 [h5py._conv] Creating converter from 5 to 7
#  2025-03-11 15:06:53,796 [h5py._conv] Creating converter from 7 to 5
#  2025-03-11 15:06:53,796 [h5py._conv] Creating converter from 5 to 7
#  2025-03-11 15:06:54,367 [mflike.ttteee] LAT_93_s0 LAT_93_s0 cl_00 (147,) 30 9000
#  2025-03-11 15:06:54,368 [mflike.ttteee] LAT_93_s0 LAT_93_s2 cl_0e (147,) 30 9000
#  2025-03-11 15:06:54,369 [mflike.ttteee] LAT_93_s2 LAT_93_s2 cl_ee (147,) 30 9000
#  2025-03-11 15:06:54,370 [mflike.ttteee] LAT_93_s0 LAT_145_s0 cl_00 (147,) 30 9000
#  2025-03-11 15:06:54,370 [mflike.ttteee] LAT_93_s0 LAT_145_s2 cl_0e (147,) 30 9000
#  2025-03-11 15:06:54,372 [mflike.ttteee] LAT_93_s2 LAT_145_s0 cl_0e (147,) 30 9000
#  2025-03-11 15:06:54,372 [mflike.ttteee] LAT_93_s2 LAT_145_s2 cl_ee (147,) 30 9000
#  2025-03-11 15:06:54,373 [mflike.ttteee] LAT_93_s0 LAT_225_s0 cl_00 (147,) 30 9000
#  2025-03-11 15:06:54,374 [mflike.ttteee] LAT_93_s0 LAT_225_s2 cl_0e (147,) 30 9000
#  2025-03-11 15:06:54,375 [mflike.ttteee] LAT_93_s2 LAT_225_s0 cl_0e (147,) 30 9000
#  2025-03-11 15:06:54,376 [mflike.ttteee] LAT_93_s2 LAT_225_s2 cl_ee (147,) 30 9000
#  2025-03-11 15:06:54,377 [mflike.ttteee] LAT_145_s0 LAT_145_s0 cl_00 (147,) 30 9000
#  2025-03-11 15:06:54,378 [mflike.ttteee] LAT_145_s0 LAT_145_s2 cl_0e (147,) 30 9000
#  2025-03-11 15:06:54,378 [mflike.ttteee] LAT_145_s2 LAT_145_s2 cl_ee (147,) 30 9000
#  2025-03-11 15:06:54,379 [mflike.ttteee] LAT_145_s0 LAT_225_s0 cl_00 (147,) 30 9000
#  2025-03-11 15:06:54,380 [mflike.ttteee] LAT_145_s0 LAT_225_s2 cl_0e (147,) 30 9000
#  2025-03-11 15:06:54,381 [mflike.ttteee] LAT_145_s2 LAT_225_s0 cl_0e (147,) 30 9000
#  2025-03-11 15:06:54,382 [mflike.ttteee] LAT_145_s2 LAT_225_s2 cl_ee (147,) 30 9000
#  2025-03-11 15:06:54,383 [mflike.ttteee] LAT_225_s0 LAT_225_s0 cl_00 (147,) 30 9000
#  2025-03-11 15:06:54,384 [mflike.ttteee] LAT_225_s0 LAT_225_s2 cl_0e (147,) 30 9000
#  2025-03-11 15:06:54,385 [mflike.ttteee] LAT_225_s2 LAT_225_s2 cl_ee (147,) 30 9000
#  2025-03-11 15:06:56,215 [mflike.ttteee] Number of bins used: 3087
#  2025-03-11 15:06:56,232 [mflike.ttteee] Maximum multipole value: 9000
#  2025-03-11 15:06:56,235 [mflike.ttteee] Initialized!
#  2025-03-11 15:06:56,238 [model] Parameters were assigned as follows:
#  2025-03-11 15:06:56,242 [model] - mflike.TTTEEE:
#  2025-03-11 15:06:56,243 [model]      Input:  ['cal_LAT_93', 'cal_LAT_145', 'cal_LAT_225', 'calG_all', 'alpha_LAT_93', 'alpha_LAT_145', 'alpha_LAT_225', 'bandint_shift_LAT_93', 'bandint_shift_LAT_145', 'bandint_shift_LAT_225', 'calT_LAT_93', 'calT_LAT_145', 'calT_LAT_225', 'calE_LAT_93', 'calE_LAT_145', 'calE_LAT_225']
#  2025-03-11 15:06:56,244 [model]      Output: []
#  2025-03-11 15:06:56,245 [model] - camb.transfers:
#  2025-03-11 15:06:56,248 [model]      Input:  ['cosmomc_theta', 'ombh2', 'omch2', 'Alens', 'tau', 'mnu', 'nnu']
#  2025-03-11 15:06:56,249 [model]      Output: []
#  2025-03-11 15:06:56,250 [model] - camb:
#  2025-03-11 15:06:56,251 [model]      Input:  ['As', 'ns']
#  2025-03-11 15:06:56,252 [model]      Output: []
#  2025-03-11 15:06:56,254 [model] - mflike.BandpowerForeground:
#  2025-03-11 15:06:56,255 [model]      Input:  ['beta_s', 'alpha_s', 'T_effd', 'beta_d', 'a_tSZ', 'a_kSZ', 'a_p', 'beta_p', 'a_c', 'beta_c', 'a_s', 'a_gtt', 'xi', 'T_d', 'alpha_dT', 'alpha_p', 'alpha_tSZ', 'a_gte', 'a_pste', 'alpha_dE', 'a_gee', 'a_psee', 'bandint_shift_LAT_93', 'bandint_shift_LAT_145', 'bandint_shift_LAT_225']
#  2025-03-11 15:06:56,257 [model]      Output: []
#  2025-03-11 15:06:56,265 [model] Components will be computed in the order:
#  2025-03-11 15:06:56,266 [model]  - [camb.transfers, camb, mflike.BandpowerForeground, mflike.TTTEEE]
#  2025-03-11 15:06:56,266 [model] Requirements will be calculated by these components:
#  2025-03-11 15:06:56,268 [model] - fg_totals: mflike.BandpowerForeground
#  2025-03-11 15:06:56,269 [model] - Cl: camb
#  2025-03-11 15:06:56,269 [model] - CAMB_transfers: camb.transfers

# %%
my_mflike = model.likelihood["mflike.TTTEEE"]
chi2 = -2 * (model.loglikes(fg_params)[0] - my_mflike.logp_const)
# Out:
#  2025-03-11 15:06:58,160 [model] Got input parameters: {'cosmomc_theta': 0.010409, 'logA': 3.045, 'As': 2.101003120287951e-09, 'ombh2': 0.02236, 'omch2': 0.1202, 'ns': 0.9649, 'Alens': 1.0, 'tau': 0.0544, 'mnu': 0.05866025403784439, 'nnu': 3.044, 'beta_s': -2.5, 'alpha_s': 1.0, 'T_effd': 19.6, 'beta_d': 1.5, 'a_tSZ': 3.3, 'a_kSZ': 1.6, 'a_p': 6.9, 'beta_p': 2.08, 'a_c': 4.9, 'beta_c': 2.2, 'a_s': 3.1, 'a_gtt': 2.81, 'xi': 0.2, 'T_d': 9.6, 'alpha_dT': -0.6, 'alpha_p': 1.0, 'alpha_tSZ': 0.0, 'a_gte': 0.1, 'a_pste': 0.0, 'alpha_dE': -0.4, 'a_gee': 0.1, 'a_psee': 0.0, 'cal_LAT_93': 1.0, 'cal_LAT_145': 1.0, 'cal_LAT_225': 1.0, 'calG_all': 1.0, 'alpha_LAT_93': 0.0, 'alpha_LAT_145': 0.0, 'alpha_LAT_225': 0.0, 'bandint_shift_LAT_93': 0.0, 'bandint_shift_LAT_145': 0.0, 'bandint_shift_LAT_225': 0.0, 'calT_LAT_93': 1.0, 'calT_LAT_145': 1.0, 'calT_LAT_225': 1.0, 'calE_LAT_93': 1.0, 'calE_LAT_145': 1.0, 'calE_LAT_225': 1.0}
#  2025-03-11 15:06:58,167 [camb.transfers] Got parameters {'cosmomc_theta': 0.010409, 'ombh2': 0.02236, 'omch2': 0.1202, 'Alens': 1.0, 'tau': 0.0544, 'mnu': 0.05866025403784439, 'nnu': 3.044}
#  2025-03-11 15:06:58,169 [camb.transfers] Computing new state
#  2025-03-11 15:06:58,171 [camb] Setting parameters: {'cosmomc_theta': 0.010409, 'ombh2': 0.02236, 'omch2': 0.1202, 'Alens': 1.0, 'tau': 0.0544, 'mnu': 0.05866025403784439, 'nnu': 3.044} and {'lens_potential_accuracy': 1, 'WantTransfer': True, 'Transfer.high_precision': True, 'Transfer.kmax': 1.2, 'num_nu_massless': 1.044, 'num_nu_massive': 2, 'nu_mass_eigenstates': 2, 'nu_mass_fractions': [0.14763410387308012, 0.8523658961269198], 'nu_mass_numbers': [1, 1], 'share_delta_neff': False, 'lmax': 9001}
#  2025-03-11 15:06:58,191 [camb] Setting attributes of CAMBparams: {'Want_CMB': True, 'Want_cl_2D_array': False, 'WantCls': True, 'NonLinear': 'NonLinear_lens'}
#  2025-03-11 15:06:58,726 [camb] Got parameters {'As': 2.101003120287951e-09, 'ns': 0.9649}
#  2025-03-11 15:06:58,726 [camb] Computing new state
#  2025-03-11 15:06:59,037 [mflike.bandpowerforeground] Got parameters {'beta_s': -2.5, 'alpha_s': 1.0, 'T_effd': 19.6, 'beta_d': 1.5, 'a_tSZ': 3.3, 'a_kSZ': 1.6, 'a_p': 6.9, 'beta_p': 2.08, 'a_c': 4.9, 'beta_c': 2.2, 'a_s': 3.1, 'a_gtt': 2.81, 'xi': 0.2, 'T_d': 9.6, 'alpha_dT': -0.6, 'alpha_p': 1.0, 'alpha_tSZ': 0.0, 'a_gte': 0.1, 'a_pste': 0.0, 'alpha_dE': -0.4, 'a_gee': 0.1, 'a_psee': 0.0, 'bandint_shift_LAT_93': 0.0, 'bandint_shift_LAT_145': 0.0, 'bandint_shift_LAT_225': 0.0}
#  2025-03-11 15:06:59,038 [mflike.bandpowerforeground] Computing new state
#  2025-03-11 15:06:59,046 [mflike.ttteee] Got parameters {'cal_LAT_93': 1.0, 'cal_LAT_145': 1.0, 'cal_LAT_225': 1.0, 'calG_all': 1.0, 'alpha_LAT_93': 0.0, 'alpha_LAT_145': 0.0, 'alpha_LAT_225': 0.0, 'bandint_shift_LAT_93': 0.0, 'bandint_shift_LAT_145': 0.0, 'bandint_shift_LAT_225': 0.0, 'calT_LAT_93': 1.0, 'calT_LAT_145': 1.0, 'calT_LAT_225': 1.0, 'calE_LAT_93': 1.0, 'calE_LAT_145': 1.0, 'calE_LAT_225': 1.0}
#  2025-03-11 15:06:59,046 [mflike.ttteee] Computing new state
#  2025-03-11 15:06:59,063 [mflike.ttteee] Log-likelihood value computed = -45396.94926674691 (Χ² = -173435.06865754907)
#  2025-03-11 15:06:59,063 [mflike.ttteee] Computed log-likelihood = -45396.94926674691
#  2025-03-11 15:06:59,063 [model] Computed derived parameters: {'As': 2.101003120287951e-09}

# %% [markdown]
# We now store theory CMB and FG Cls and use MFLike functions to manipulate them into a data model

# %%
Dl = model.components[2].get_Cl(ell_factor=True)
fg_totals = model.components[3].get_fg_totals()

# %%
#need to define this to pass params as a single dictionary to get modified theory below
params = {**cosmo_params,**fg_params}
params = {**params, **nuisance_params}
print(params)
# Out:
# {'cosmomc_theta': 0.010409, 'logA': {'value': 3.045, 'drop': True}, 'As': {'value': 'lambda logA: 1e-10*np.exp(logA)'}, 'ombh2': 0.02236, 'omch2': 0.1202, 'ns': 0.9649, 'Alens': 1.0, 'tau': 0.0544, 'mnu': 0.05866025403784439, 'nnu': 3.044, 'a_tSZ': 3.3, 'a_kSZ': 1.6, 'a_p': 6.9, 'beta_p': 2.08, 'a_c': 4.9, 'beta_c': 2.2, 'a_s': 3.1, 'T_d': 9.6, 'a_gtt': 2.81, 'a_gte': 0.1, 'a_gee': 0.1, 'a_psee': 0.0, 'a_pste': 0.0, 'xi': 0.2, 'bandint_shift_93': 0, 'bandint_shift_145': 0, 'bandint_shift_225': 0, 'cal_LAT_93': 1, 'cal_LAT_145': 1, 'cal_LAT_225': 1, 'calT_LAT_93': 1, 'calT_LAT_145': 1, 'calT_LAT_225': 1, 'calE_LAT_93': 1, 'calE_LAT_145': 1, 'calE_LAT_225': 1, 'calG_all': 1, 'alpha_LAT_93': 0, 'alpha_LAT_145': 0, 'alpha_LAT_225': 0}

# %%
mflike = model.components[0]
dls = {s: Dl[s][mflike.l_bpws] for s, _ in mflike.lcuts.items()}
#combine CMB and FG and add svstematics
DlsObs = mflike.get_modified_theory(dls, fg_totals, **params)

# %% [markdown]
# We now bin the theory data model

# %%
ps_dic = {}
ps_vec = np.zeros_like(model.components[0].data_vec)

for m in model.components[0].spec_meta:
    p = m["pol"]
    ids = m["ids"]
    w = m["bpw"]
    t1 = m["t1"]
    t2 = m["t2"]
    
    #print(p, ids, t1, t2)
    if (t1+"x"+t2 not in ps_dic.keys ()):
        ps_dic[t1+"x"+t2]={"lbin": m["leff"]}
        
    dls_obs = DlsObs[p, m["t2"], m["t1"]] if m["hasYX_xsp"] else DlsObs[p, m["t1"], m["t2"]]
    for i, nonzero, weights in zip (m["ids"], w.nonzeros, w.sliced_weights):
        ps_vec[i] = weights @ dls_obs[nonzero]
        
    ps_dic[t1+"x"+t2].update({p: ps_vec[ids]})

# %%
ps_dic.keys() #check that all spectra are here
# Out:
# dict_keys(['LAT_93xLAT_93', 'LAT_93xLAT_145', 'LAT_93xLAT_225', 'LAT_145xLAT_145', 'LAT_145xLAT_225', 'LAT_225xLAT_225'])

# %% [markdown]
# We now save the spectra in the format needed by ```sacc```: lbin,TT,TE,TB,ET,BT,EE,EB,BE,BB

# %%
namedir=packages_path+"/data/soliket_mflike/smooth_data/split_mflike/"
#namedir="/Users/bradamante/Google Drive/My Drive/Work/Projects/Open/cobaya_packages/data/soliket_mflike/smooth_data/"
for k in ps_dic.keys():
    namefile = "Dl_"+k+"_auto_00000.dat"
    l = ps_dic[k]["lbin"]
    tt = ps_dic[k]["tt"]
    te = ps_dic[k]["te"]
    ee = ps_dic[k]["ee"]
    tbebbb = np.zeros(len(l))
    np.savetxt(namedir+namefile,np.column_stack((l,tt,te,tbebbb,te,tbebbb,ee,tbebbb,tbebbb,tbebbb)))

# %%
cltest=np.loadtxt(namedir+namefile)

# %%
cltest.shape
# Out:
# (147, 10)

# %% [markdown]
# We now use the routine in ``PSPype`` to convert the .txt data in sacc data. We first read the spectra:

# %%
data = {}
sim_suffix = "00000"
for spec_name in ps_dic.keys():
    na, nb = spec_name.split("x")
    data[na,nb] = {}
    spec = np.loadtxt("%s/Dl_%s_auto_%s.dat" % (namedir, spec_name, sim_suffix), unpack=True)
    ps = {"lbin": spec[0],
          "TT": spec[1],
          "TE": spec[2],
          "TB": spec[3],
          "ET": spec[4],
          "BT": spec[5],
          "EE": spec[6],
          "EB": spec[7],
          "BE": spec[8],
          "BB": spec[9]}
    data[na,nb] = ps

# %% [markdown]
# Then define useful functions

# %%
exp_freq = ['LAT_93', 'LAT_145', 'LAT_225']
pols = ["T", "E", "B"]
map_types = {"T": "0", "E": "e", "B": "b"}

def get_x_iterator():
    for id_efa, efa in enumerate(exp_freq):
        for id_efb, efb in enumerate(exp_freq):
            if (id_efa > id_efb): continue
            for ipa, pa in enumerate(pols):
                if (efa == efb):
                    polsb = pols[ipa:]
                else:
                    polsb = pols
                for pb in polsb:
                    yield (efa, efb, pa, pb)
                    print(efa, efb, pa, pb)

# %% [markdown]
# Import ```sacc``` and start adding info

# %%
import sacc

spec_sacc =  sacc.Sacc()

# %%
for exp_f in exp_freq:
    print("%s_s0" % (exp_f))

    my_data_bandpasses = {"nu":np.array([float(exp_f.split("_")[1])]), "b_nu":np.array([1.])}
    my_data_beams = {"l":np.arange(10000), "bl":np.ones(10000)}

    # CMB temperature 
    spec_sacc.add_tracer("NuMap", "%s_s0" % (exp_f),
                                 quantity="cmb_temperature", spin=0,
                                 nu=model.components[0].bands[exp_f+"_s0"]["nu"],
                                 bandpass=model.components[0].bands[exp_f+"_s0"]["bandpass"],
                                 ell=my_data_beams["l"],
                                 beam=my_data_beams["bl"])
    
    # CMB polarization
    spec_sacc.add_tracer("NuMap", "%s_s2" % (exp_f),
                                 quantity="cmb_polarization", spin=2,
                                 nu=model.components[0].bands[exp_f+"_s2"]["nu"],
                                 bandpass=model.components[0].bands[exp_f+"_s2"]["bandpass"],
                                 ell=my_data_beams["l"],
                                 beam=my_data_beams["bl"])
# Out:
# LAT_93_s0
# LAT_145_s0
# LAT_225_s0

# %% [markdown]
# Now add spectra to sacc object and save in fits format

# %%
for id_x, (efa, efb, pa, pb) in enumerate(get_x_iterator()):
    if pa == "T":
        ta_name = "%s_s0" % (efa)
    else:
        ta_name = "%s_s2" % (efa)

    if pb == "T":
        tb_name = "%s_s0" % (efb)
    else:
        tb_name = "%s_s2" % (efb)

    if pb == "T":
        cl_type = "cl_" + map_types[pb] + map_types[pa]
    else:
        cl_type = "cl_" + map_types[pa] + map_types[pb]

    lbin = data[efa, efb]["lbin"]
    cb = data[efa, efb][pa + pb]

    spec_sacc.add_ell_cl(cl_type, ta_name, tb_name, lbin, cb)
# Out:
# LAT_93 LAT_93 T T
# LAT_93 LAT_93 T E
# LAT_93 LAT_93 T B
# LAT_93 LAT_93 E E
# LAT_93 LAT_93 E B
# LAT_93 LAT_93 B B
# LAT_93 LAT_145 T T
# LAT_93 LAT_145 T E
# LAT_93 LAT_145 T B
# LAT_93 LAT_145 E T
# LAT_93 LAT_145 E E
# LAT_93 LAT_145 E B
# LAT_93 LAT_145 B T
# LAT_93 LAT_145 B E
# LAT_93 LAT_145 B B
# LAT_93 LAT_225 T T
# LAT_93 LAT_225 T E
# LAT_93 LAT_225 T B
# LAT_93 LAT_225 E T
# LAT_93 LAT_225 E E
# LAT_93 LAT_225 E B
# LAT_93 LAT_225 B T
# LAT_93 LAT_225 B E
# LAT_93 LAT_225 B B
# LAT_145 LAT_145 T T
# LAT_145 LAT_145 T E
# LAT_145 LAT_145 T B
# LAT_145 LAT_145 E E
# LAT_145 LAT_145 E B
# LAT_145 LAT_145 B B
# LAT_145 LAT_225 T T
# LAT_145 LAT_225 T E
# LAT_145 LAT_225 T B
# LAT_145 LAT_225 E T
# LAT_145 LAT_225 E E
# LAT_145 LAT_225 E B
# LAT_145 LAT_225 B T
# LAT_145 LAT_225 B E
# LAT_145 LAT_225 B B
# LAT_225 LAT_225 T T
# LAT_225 LAT_225 T E
# LAT_225 LAT_225 T B
# LAT_225 LAT_225 E E
# LAT_225 LAT_225 E B
# LAT_225 LAT_225 B B

# %%
spec_sacc.save_fits("%s/data_sacc_smooth_%s.fits" % (namedir, sim_suffix), overwrite=True)

# %% [markdown]
# # Test new data
#
# Let's read the newly created data and check that we get chi2=0 if compared against same fiducial

# %%
pre = "data_sacc_smooth_"
info = {
    "likelihood": {
    "mflike.TTTEEE": {
        "package_install": "pip",
        "data_folder": namedir,
        "input_file": pre + "00000.fits",
        "cov_Bbl_file": packages_path + "/data/MFLike/v0.8/data_sacc_w_covar_and_Bbl.fits",
        "defaults": {"polarizations": ["TT","TE","ET","EE"],
                     "scales": {"TT": [30, 9000],
                                "TE": [30, 9000],
                                "ET": [30, 9000],
                                "EE": [30, 9000]},
                     "symmetrize": False
                    },
    }
},
        "theory": {"camb": {"extra_args": {"lens_potential_accuracy": 1,
                                           "WantTransfer": True,
                                           "Transfer.high_precision": True,
                                           "Transfer.kmax": 1.2,
                                           "num_nu_massless": 1.044, #we use the minimal normal ordering case: massless lightest state, m2 and m3
                                           "num_nu_massive": 2,
                                           "nu_mass_eigenstates": 2,
                                           "nu_mass_fractions": [f2,f3],
                                           "nu_mass_numbers": [1,1],
                                           "share_delta_neff": False},
                            "stop_at_error": True}},
        "params": cosmo_params,
        "packages_path": packages_path,
        "debug": True,
}

# %%
info["theory"]["mflike.BandpowerForeground"] = {'stop_at_error': True}

# %%
from cobaya.model import get_model

model_test = get_model(info)
# Out:
#  2025-03-11 15:07:27,196 [input] 'mflike.BandpowerForeground' could not be found as internal, trying external.
#  2025-03-11 15:07:27,230 [input] 'mflike.TTTEEE' could not be found as internal, trying external.
#  2025-03-11 15:07:27,255 [model] Input info updated with defaults (dumped to YAML):
# theory:
#   camb:
#     version: null
#     path: null
#     speed: 0.3
#     stop_at_error: true
#     extra_args:
#       lens_potential_accuracy: 1
#       WantTransfer: true
#       Transfer.high_precision: true
#       Transfer.kmax: 1.2
#       num_nu_massless: 1.044
#       num_nu_massive: 2
#       nu_mass_eigenstates: 2
#       nu_mass_fractions:
#       - 0.14763410387308012
#       - 0.8523658961269198
#       nu_mass_numbers:
#       - 1
#       - 1
#       share_delta_neff: false
#     ignore_obsolete: false
#     use_renames: false
#     external_primordial_pk: false
#     renames:
#       omegabh2: ombh2
#       omegach2: omch2
#       omegal: omega_de
#       omegak: omk
#       yhe: YHe
#       yheused: YHe
#       YpBBN: Y_p
#   mflike.BandpowerForeground:
#     top_hat_band: null
#     bands: null
#     beams: null
#     beam_profile: null
#     requested_cls:
#     - tt
#     - te
#     - ee
#     lmin: 2
#     lmax: 6001
#     ells: null
#     experiments:
#     - LAT_93
#     - LAT_145
#     - LAT_225
#     bandint_freqs:
#     - 93.0
#     - 145.0
#     - 225.0
#     normalisation:
#       nu_0: 150.0
#       ell_0: 3000
#       T_CMB: 2.725
#     components:
#       tt:
#       - kSZ
#       - tSZ_and_CIB
#       - cibp
#       - dust
#       - radio
#       te:
#       - radio
#       - dust
#       ee:
#       - radio
#       - dust
#     params:
#       beta_s:
#         value: -2.5
#         latex: \beta_s
#       alpha_s:
#         value: 1.0
#         latex: \alpha_s
#       T_effd:
#         value: 19.6
#         latex: T_{\mathrm{dust},\mathrm{eff}}
#       beta_d:
#         value: 1.5
#         latex: \beta_\mathrm{dust}
#       a_tSZ:
#         prior:
#           min: 3.0
#           max: 3.6
#         proposal: 0.05
#         latex: a_\mathrm{tSZ}
#       a_kSZ:
#         prior:
#           min: 1.4
#           max: 1.8
#         proposal: 0.1
#         latex: a_\mathrm{kSZ}
#       a_p:
#         prior:
#           min: 6.2
#           max: 7.6
#         proposal: 0.075
#         latex: a_p
#       beta_p:
#         prior:
#           min: 1.8
#           max: 2.2
#         proposal: 0.015
#         latex: \beta_p
#       a_c:
#         prior:
#           min: 4.4
#           max: 5.4
#         proposal: 0.12
#         latex: a_c
#       beta_c:
#         prior:
#           min: 2.0
#           max: 2.4
#         proposal: 0.03
#         latex: \beta_c
#       a_s:
#         prior:
#           min: 2.8
#           max: 3.4
#         proposal: 0.01
#         latex: a_s
#       a_gtt:
#         prior:
#           dist: norm
#           loc: 2.79
#           scale: 0.45
#         proposal: 0.4
#         latex: a_\mathrm{dust}^\mathrm{TT}
#       xi:
#         prior:
#           min: 0
#           max: 0.2
#         proposal: 0.05
#         latex: \xi
#       T_d:
#         prior:
#           min: 8.6
#           max: 10.6
#         proposal: 0.6
#         latex: T_d
#       alpha_dT:
#         value: -0.6
#         latex: \alpha_{\mathrm{dust},T}
#       alpha_p:
#         value: 1.0
#         latex: \alpha_p
#       alpha_tSZ:
#         value: 0.0
#         latex: \alpha_{\rm tSZ}
#       a_gte:
#         prior:
#           dist: norm
#           loc: 0.36
#           scale: 0.04
#         proposal: 0.04
#         latex: a_\mathrm{dust}^\mathrm{TE}
#       a_pste:
#         prior:
#           min: -1
#           max: 1
#         proposal: 0.05
#         latex: a_\mathrm{ps}^\mathrm{TE}
#       alpha_dE:
#         value: -0.4
#         latex: \alpha_{\mathrm{dust},E}
#       a_gee:
#         prior:
#           dist: norm
#           loc: 0.13
#           scale: 0.03
#         proposal: 0.03
#         latex: a_\mathrm{dust}^\mathrm{EE}
#       a_psee:
#         prior:
#           min: 0
#         proposal: 0.05
#         latex: a_\mathrm{ps}^\mathrm{EE}
#     speed: -1
#     stop_at_error: true
#     version: null
# likelihood:
#   mflike.TTTEEE:
#     requested_cls:
#     - tt
#     - te
#     - ee
#     defaults:
#       polarizations:
#       - TT
#       - TE
#       - ET
#       - EE
#       scales:
#         TT:
#         - 30
#         - 9000
#         TE:
#         - 30
#         - 9000
#         ET:
#         - 30
#         - 9000
#         EE:
#         - 30
#         - 9000
#       symmetrize: false
#     params:
#       cal_LAT_93:
#         value: 1
#         latex: \mathrm{Cal}^{93}
#       cal_LAT_145:
#         value: 1
#         latex: \mathrm{Cal}^{145}
#       cal_LAT_225:
#         value: 1
#         latex: \mathrm{Cal}^{225}
#       calG_all:
#         value: 1
#         latex: \mathrm{Cal}_{\rm G}^{\rm All}
#       alpha_LAT_93:
#         value: 0
#         latex: \alpha^{93}
#       alpha_LAT_145:
#         value: 0
#         latex: \alpha^{145}
#       alpha_LAT_225:
#         value: 0
#         latex: \alpha^{225}
#       bandint_shift_LAT_93:
#         value: 0
#         latex: \Delta_{\rm band}^{93}
#       bandint_shift_LAT_145:
#         value: 0
#         latex: \Delta_{\rm band}^{145}
#       bandint_shift_LAT_225:
#         value: 0
#         latex: \Delta_{\rm band}^{225}
#       calT_LAT_93:
#         value: 1
#         latex: \mathrm{Cal}_{\rm T}^{93}
#       calT_LAT_145:
#         value: 1
#         latex: \mathrm{Cal}_{\rm T}^{145}
#       calT_LAT_225:
#         value: 1
#         latex: \mathrm{Cal}_{\rm T}^{225}
#       calE_LAT_93:
#         value: 1
#         latex: \mathrm{Cal}_{\rm E}^{93}
#       calE_LAT_145:
#         value: 1
#         latex: \mathrm{Cal}_{\rm E}^{145}
#       calE_LAT_225:
#         value: 1
#         latex: \mathrm{Cal}_{\rm E}^{225}
#     data_folder: /Users/bradamante/Library/CloudStorage/GoogleDrive-grbmtn@unife.it/My
#       Drive/Work/Projects/Open/cobaya_packages/data/soliket_mflike/smooth_data/split_mflike/
#     input_file: data_sacc_smooth_00000.fits
#     cov_Bbl_file: /Users/bradamante/Library/CloudStorage/GoogleDrive-grbmtn@unife.it/My
#       Drive/Work/Projects/Open/cobaya_packages/data/MFLike/v0.8/data_sacc_w_covar_and_Bbl.fits
#     lmax_theory: null
#     data:
#       experiments:
#       - LAT_93
#       - LAT_145
#       - LAT_225
#       spectra:
#       - experiments:
#         - LAT_93
#         - LAT_93
#       - experiments:
#         - LAT_93
#         - LAT_145
#       - experiments:
#         - LAT_93
#         - LAT_225
#       - experiments:
#         - LAT_145
#         - LAT_145
#       - experiments:
#         - LAT_145
#         - LAT_225
#       - experiments:
#         - LAT_225
#         - LAT_225
#     systematics_template: null
#     type: []
#     speed: -1
#     stop_at_error: false
#     version: null
#     package_install: pip
# params:
#   cosmomc_theta:
#     value: 0.010409
#   logA:
#     value: 3.045
#     drop: true
#   As:
#     value: 'lambda logA: 1e-10*np.exp(logA)'
#     derived: true
#   ombh2:
#     value: 0.02236
#     renames:
#     - omegabh2
#   omch2:
#     value: 0.1202
#     renames:
#     - omegach2
#   ns:
#     value: 0.9649
#   Alens:
#     value: 1.0
#   tau:
#     value: 0.0544
#   mnu:
#     value: 0.05866025403784439
#   nnu:
#     value: 3.044
#   beta_s:
#     value: -2.5
#     latex: \beta_s
#   alpha_s:
#     value: 1.0
#     latex: \alpha_s
#   T_effd:
#     value: 19.6
#     latex: T_{\mathrm{dust},\mathrm{eff}}
#   beta_d:
#     value: 1.5
#     latex: \beta_\mathrm{dust}
#   a_tSZ:
#     prior:
#       min: 3.0
#       max: 3.6
#     proposal: 0.05
#     latex: a_\mathrm{tSZ}
#   a_kSZ:
#     prior:
#       min: 1.4
#       max: 1.8
#     proposal: 0.1
#     latex: a_\mathrm{kSZ}
#   a_p:
#     prior:
#       min: 6.2
#       max: 7.6
#     proposal: 0.075
#     latex: a_p
#   beta_p:
#     prior:
#       min: 1.8
#       max: 2.2
#     proposal: 0.015
#     latex: \beta_p
#   a_c:
#     prior:
#       min: 4.4
#       max: 5.4
#     proposal: 0.12
#     latex: a_c
#   beta_c:
#     prior:
#       min: 2.0
#       max: 2.4
#     proposal: 0.03
#     latex: \beta_c
#   a_s:
#     prior:
#       min: 2.8
#       max: 3.4
#     proposal: 0.01
#     latex: a_s
#   a_gtt:
#     prior:
#       dist: norm
#       loc: 2.79
#       scale: 0.45
#     proposal: 0.4
#     latex: a_\mathrm{dust}^\mathrm{TT}
#   xi:
#     prior:
#       min: 0
#       max: 0.2
#     proposal: 0.05
#     latex: \xi
#   T_d:
#     prior:
#       min: 8.6
#       max: 10.6
#     proposal: 0.6
#     latex: T_d
#   alpha_dT:
#     value: -0.6
#     latex: \alpha_{\mathrm{dust},T}
#   alpha_p:
#     value: 1.0
#     latex: \alpha_p
#   alpha_tSZ:
#     value: 0.0
#     latex: \alpha_{\rm tSZ}
#   a_gte:
#     prior:
#       dist: norm
#       loc: 0.36
#       scale: 0.04
#     proposal: 0.04
#     latex: a_\mathrm{dust}^\mathrm{TE}
#   a_pste:
#     prior:
#       min: -1
#       max: 1
#     proposal: 0.05
#     latex: a_\mathrm{ps}^\mathrm{TE}
#   alpha_dE:
#     value: -0.4
#     latex: \alpha_{\mathrm{dust},E}
#   a_gee:
#     prior:
#       dist: norm
#       loc: 0.13
#       scale: 0.03
#     proposal: 0.03
#     latex: a_\mathrm{dust}^\mathrm{EE}
#   a_psee:
#     prior:
#       min: 0
#     proposal: 0.05
#     latex: a_\mathrm{ps}^\mathrm{EE}
#   cal_LAT_93:
#     value: 1
#     latex: \mathrm{Cal}^{93}
#   cal_LAT_145:
#     value: 1
#     latex: \mathrm{Cal}^{145}
#   cal_LAT_225:
#     value: 1
#     latex: \mathrm{Cal}^{225}
#   calG_all:
#     value: 1
#     latex: \mathrm{Cal}_{\rm G}^{\rm All}
#   alpha_LAT_93:
#     value: 0
#     latex: \alpha^{93}
#   alpha_LAT_145:
#     value: 0
#     latex: \alpha^{145}
#   alpha_LAT_225:
#     value: 0
#     latex: \alpha^{225}
#   bandint_shift_LAT_93:
#     value: 0
#     latex: \Delta_{\rm band}^{93}
#   bandint_shift_LAT_145:
#     value: 0
#     latex: \Delta_{\rm band}^{145}
#   bandint_shift_LAT_225:
#     value: 0
#     latex: \Delta_{\rm band}^{225}
#   calT_LAT_93:
#     value: 1
#     latex: \mathrm{Cal}_{\rm T}^{93}
#   calT_LAT_145:
#     value: 1
#     latex: \mathrm{Cal}_{\rm T}^{145}
#   calT_LAT_225:
#     value: 1
#     latex: \mathrm{Cal}_{\rm T}^{225}
#   calE_LAT_93:
#     value: 1
#     latex: \mathrm{Cal}_{\rm E}^{93}
#   calE_LAT_145:
#     value: 1
#     latex: \mathrm{Cal}_{\rm E}^{145}
#   calE_LAT_225:
#     value: 1
#     latex: \mathrm{Cal}_{\rm E}^{225}
# packages_path: /Users/bradamante/Library/CloudStorage/GoogleDrive-grbmtn@unife.it/My
#   Drive/Work/Projects/Open/cobaya_packages
# debug: true
#
#  2025-03-11 15:07:27,266 [camb] Attempting import of Cobaya-installed version, but defaulting to global import if not found.
#  2025-03-11 15:07:27,266 [camb] 'camb' to be imported from (sub)directory /Users/bradamante/Library/CloudStorage/GoogleDrive-grbmtn@unife.it/My Drive/Work/Projects/Open/cobaya_packages/code/CAMB
#  2025-03-11 15:07:27,268 [camb] Could not import 'camb' from /Users/bradamante/Library/CloudStorage/GoogleDrive-grbmtn@unife.it/My Drive/Work/Projects/Open/cobaya_packages/code/CAMB: Module camb successfully loaded, but not from requested path: /Users/bradamante/Library/CloudStorage/GoogleDrive-grbmtn@unife.it/My Drive/Work/Projects/Open/cobaya_packages/code/CAMB, but instead from /Users/bradamante/miniconda/envs/soliket-tests/lib/python3.10/site-packages/camb
#  2025-03-11 15:07:27,268 [camb] Defaulting to global import.
#  2025-03-11 15:07:27,269 [camb] `camb` module loaded successfully from /Users/bradamante/miniconda/envs/soliket-tests/lib/python3.10/site-packages/camb
#  2025-03-11 15:07:27,270 [theorycollection] 'mflike.BandpowerForeground' could not be found as internal, trying external.
#  2025-03-11 15:07:27,353 [likelihoodcollection] 'mflike.TTTEEE' could not be found as internal, trying external.
#  2025-03-11 15:07:27,980 [mflike.ttteee] LAT_93_s0 LAT_93_s0 cl_00 (147,) 30 9000
#  2025-03-11 15:07:27,982 [mflike.ttteee] LAT_93_s0 LAT_93_s2 cl_0e (147,) 30 9000
#  2025-03-11 15:07:27,983 [mflike.ttteee] LAT_93_s2 LAT_93_s2 cl_ee (147,) 30 9000
#  2025-03-11 15:07:27,984 [mflike.ttteee] LAT_93_s0 LAT_145_s0 cl_00 (147,) 30 9000
#  2025-03-11 15:07:27,985 [mflike.ttteee] LAT_93_s0 LAT_145_s2 cl_0e (147,) 30 9000
#  2025-03-11 15:07:27,986 [mflike.ttteee] LAT_93_s2 LAT_145_s0 cl_0e (147,) 30 9000
#  2025-03-11 15:07:27,988 [mflike.ttteee] LAT_93_s2 LAT_145_s2 cl_ee (147,) 30 9000
#  2025-03-11 15:07:27,989 [mflike.ttteee] LAT_93_s0 LAT_225_s0 cl_00 (147,) 30 9000
#  2025-03-11 15:07:27,990 [mflike.ttteee] LAT_93_s0 LAT_225_s2 cl_0e (147,) 30 9000
#  2025-03-11 15:07:27,992 [mflike.ttteee] LAT_93_s2 LAT_225_s0 cl_0e (147,) 30 9000
#  2025-03-11 15:07:27,993 [mflike.ttteee] LAT_93_s2 LAT_225_s2 cl_ee (147,) 30 9000
#  2025-03-11 15:07:27,994 [mflike.ttteee] LAT_145_s0 LAT_145_s0 cl_00 (147,) 30 9000
#  2025-03-11 15:07:27,996 [mflike.ttteee] LAT_145_s0 LAT_145_s2 cl_0e (147,) 30 9000
#  2025-03-11 15:07:27,997 [mflike.ttteee] LAT_145_s2 LAT_145_s2 cl_ee (147,) 30 9000
#  2025-03-11 15:07:27,998 [mflike.ttteee] LAT_145_s0 LAT_225_s0 cl_00 (147,) 30 9000
#  2025-03-11 15:07:28,000 [mflike.ttteee] LAT_145_s0 LAT_225_s2 cl_0e (147,) 30 9000
#  2025-03-11 15:07:28,001 [mflike.ttteee] LAT_145_s2 LAT_225_s0 cl_0e (147,) 30 9000
#  2025-03-11 15:07:28,002 [mflike.ttteee] LAT_145_s2 LAT_225_s2 cl_ee (147,) 30 9000
#  2025-03-11 15:07:28,003 [mflike.ttteee] LAT_225_s0 LAT_225_s0 cl_00 (147,) 30 9000
#  2025-03-11 15:07:28,004 [mflike.ttteee] LAT_225_s0 LAT_225_s2 cl_0e (147,) 30 9000
#  2025-03-11 15:07:28,006 [mflike.ttteee] LAT_225_s2 LAT_225_s2 cl_ee (147,) 30 9000
#  2025-03-11 15:07:29,804 [mflike.ttteee] Number of bins used: 3087
#  2025-03-11 15:07:29,840 [mflike.ttteee] Maximum multipole value: 9000
#  2025-03-11 15:07:29,842 [mflike.ttteee] Initialized!
#  2025-03-11 15:07:29,847 [model] Parameters were assigned as follows:
#  2025-03-11 15:07:29,848 [model] - mflike.TTTEEE:
#  2025-03-11 15:07:29,849 [model]      Input:  ['cal_LAT_93', 'cal_LAT_145', 'cal_LAT_225', 'calG_all', 'alpha_LAT_93', 'alpha_LAT_145', 'alpha_LAT_225', 'bandint_shift_LAT_93', 'bandint_shift_LAT_145', 'bandint_shift_LAT_225', 'calT_LAT_93', 'calT_LAT_145', 'calT_LAT_225', 'calE_LAT_93', 'calE_LAT_145', 'calE_LAT_225']
#  2025-03-11 15:07:29,849 [model]      Output: []
#  2025-03-11 15:07:29,850 [model] - camb.transfers:
#  2025-03-11 15:07:29,850 [model]      Input:  ['cosmomc_theta', 'ombh2', 'omch2', 'Alens', 'tau', 'mnu', 'nnu']
#  2025-03-11 15:07:29,851 [model]      Output: []
#  2025-03-11 15:07:29,851 [model] - camb:
#  2025-03-11 15:07:29,852 [model]      Input:  ['As', 'ns']
#  2025-03-11 15:07:29,852 [model]      Output: []
#  2025-03-11 15:07:29,853 [model] - mflike.BandpowerForeground:
#  2025-03-11 15:07:29,855 [model]      Input:  ['beta_s', 'alpha_s', 'T_effd', 'beta_d', 'a_tSZ', 'a_kSZ', 'a_p', 'beta_p', 'a_c', 'beta_c', 'a_s', 'a_gtt', 'xi', 'T_d', 'alpha_dT', 'alpha_p', 'alpha_tSZ', 'a_gte', 'a_pste', 'alpha_dE', 'a_gee', 'a_psee', 'bandint_shift_LAT_93', 'bandint_shift_LAT_145', 'bandint_shift_LAT_225']
#  2025-03-11 15:07:29,856 [model]      Output: []
#  2025-03-11 15:07:29,860 [model] Components will be computed in the order:
#  2025-03-11 15:07:29,861 [model]  - [camb.transfers, camb, mflike.BandpowerForeground, mflike.TTTEEE]
#  2025-03-11 15:07:29,862 [model] Requirements will be calculated by these components:
#  2025-03-11 15:07:29,865 [model] - fg_totals: mflike.BandpowerForeground
#  2025-03-11 15:07:29,865 [model] - Cl: camb
#  2025-03-11 15:07:29,867 [model] - CAMB_transfers: camb.transfers

# %%
my_mflike = model_test.likelihood["mflike.TTTEEE"]
chi2 = -2 * (model_test.loglikes(fg_params)[0] - my_mflike.logp_const)
# Out:
#  2025-03-11 15:07:31,577 [model] Got input parameters: {'cosmomc_theta': 0.010409, 'logA': 3.045, 'As': 2.101003120287951e-09, 'ombh2': 0.02236, 'omch2': 0.1202, 'ns': 0.9649, 'Alens': 1.0, 'tau': 0.0544, 'mnu': 0.05866025403784439, 'nnu': 3.044, 'beta_s': -2.5, 'alpha_s': 1.0, 'T_effd': 19.6, 'beta_d': 1.5, 'a_tSZ': 3.3, 'a_kSZ': 1.6, 'a_p': 6.9, 'beta_p': 2.08, 'a_c': 4.9, 'beta_c': 2.2, 'a_s': 3.1, 'a_gtt': 2.81, 'xi': 0.2, 'T_d': 9.6, 'alpha_dT': -0.6, 'alpha_p': 1.0, 'alpha_tSZ': 0.0, 'a_gte': 0.1, 'a_pste': 0.0, 'alpha_dE': -0.4, 'a_gee': 0.1, 'a_psee': 0.0, 'cal_LAT_93': 1.0, 'cal_LAT_145': 1.0, 'cal_LAT_225': 1.0, 'calG_all': 1.0, 'alpha_LAT_93': 0.0, 'alpha_LAT_145': 0.0, 'alpha_LAT_225': 0.0, 'bandint_shift_LAT_93': 0.0, 'bandint_shift_LAT_145': 0.0, 'bandint_shift_LAT_225': 0.0, 'calT_LAT_93': 1.0, 'calT_LAT_145': 1.0, 'calT_LAT_225': 1.0, 'calE_LAT_93': 1.0, 'calE_LAT_145': 1.0, 'calE_LAT_225': 1.0}
#  2025-03-11 15:07:31,579 [camb.transfers] Got parameters {'cosmomc_theta': 0.010409, 'ombh2': 0.02236, 'omch2': 0.1202, 'Alens': 1.0, 'tau': 0.0544, 'mnu': 0.05866025403784439, 'nnu': 3.044}
#  2025-03-11 15:07:31,584 [camb.transfers] Computing new state
#  2025-03-11 15:07:31,585 [camb] Setting parameters: {'cosmomc_theta': 0.010409, 'ombh2': 0.02236, 'omch2': 0.1202, 'Alens': 1.0, 'tau': 0.0544, 'mnu': 0.05866025403784439, 'nnu': 3.044} and {'lens_potential_accuracy': 1, 'WantTransfer': True, 'Transfer.high_precision': True, 'Transfer.kmax': 1.2, 'num_nu_massless': 1.044, 'num_nu_massive': 2, 'nu_mass_eigenstates': 2, 'nu_mass_fractions': [0.14763410387308012, 0.8523658961269198], 'nu_mass_numbers': [1, 1], 'share_delta_neff': False, 'lmax': 9001}
#  2025-03-11 15:07:31,599 [camb] Setting attributes of CAMBparams: {'Want_CMB': True, 'Want_cl_2D_array': False, 'WantCls': True, 'NonLinear': 'NonLinear_lens'}
#  2025-03-11 15:07:32,143 [camb] Got parameters {'As': 2.101003120287951e-09, 'ns': 0.9649}
#  2025-03-11 15:07:32,144 [camb] Computing new state
#  2025-03-11 15:07:32,431 [mflike.bandpowerforeground] Got parameters {'beta_s': -2.5, 'alpha_s': 1.0, 'T_effd': 19.6, 'beta_d': 1.5, 'a_tSZ': 3.3, 'a_kSZ': 1.6, 'a_p': 6.9, 'beta_p': 2.08, 'a_c': 4.9, 'beta_c': 2.2, 'a_s': 3.1, 'a_gtt': 2.81, 'xi': 0.2, 'T_d': 9.6, 'alpha_dT': -0.6, 'alpha_p': 1.0, 'alpha_tSZ': 0.0, 'a_gte': 0.1, 'a_pste': 0.0, 'alpha_dE': -0.4, 'a_gee': 0.1, 'a_psee': 0.0, 'bandint_shift_LAT_93': 0.0, 'bandint_shift_LAT_145': 0.0, 'bandint_shift_LAT_225': 0.0}
#  2025-03-11 15:07:32,431 [mflike.bandpowerforeground] Computing new state
#  2025-03-11 15:07:32,438 [mflike.ttteee] Got parameters {'cal_LAT_93': 1.0, 'cal_LAT_145': 1.0, 'cal_LAT_225': 1.0, 'calG_all': 1.0, 'alpha_LAT_93': 0.0, 'alpha_LAT_145': 0.0, 'alpha_LAT_225': 0.0, 'bandint_shift_LAT_93': 0.0, 'bandint_shift_LAT_145': 0.0, 'bandint_shift_LAT_225': 0.0, 'calT_LAT_93': 1.0, 'calT_LAT_145': 1.0, 'calT_LAT_225': 1.0, 'calE_LAT_93': 1.0, 'calE_LAT_145': 1.0, 'calE_LAT_225': 1.0}
#  2025-03-11 15:07:32,438 [mflike.ttteee] Computing new state
#  2025-03-11 15:07:32,470 [mflike.ttteee] Log-likelihood value computed = -2038.1821023596394 (Χ² = -0.0)
#  2025-03-11 15:07:32,471 [mflike.ttteee] Computed log-likelihood = -2038.1821023596394
#  2025-03-11 15:07:32,471 [model] Computed derived parameters: {'As': 2.101003120287951e-09}

# %%
chi2
# Out:
# array([-0.])

# %% [markdown]
# Awesome!!!
